# %%
# Monting Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/MyDrive/Deusto/Cuarto/NLP/NLP Grupo/Codigo"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1tbwtJBZplHfm91lceTlpEA9t4RR96dyM/NLP Grupo/Codigo

# %%
import pandas as pd
from nltk.tokenize.casual import casual_tokenize
from sklearn.model_selection import train_test_split

# %% [markdown]
# # ⏲ Preparing Datasets for classification

# %%
df_final_classify_processed = pd.read_csv("../Datasets/dataset_clasificador_final/classify_char_processed.csv")

df_final_classify_raw = pd.read_csv("../Datasets/dataset_clasificador_final/classify_char_raw.csv")

df_final_classyfy_mistTest_p16Train_raw = pd.read_csv("../Datasets/dataset_clasificador_final/classify_mistTest_p16Train_raw.csv")

# %%
df_final_classify_processed.head(10)
# Out:
#   char                                               mods target  split
# 0  Vin  about thankful right young happy hesitant mist...   istp  train
# 1  NaN  negative guide whole personally get overcommit...   enfj  train
# 2  Vin  kid responsible old fool accustomed person eff...   istp  train
# 3  NaN  purpose born tend much greater find overly fee...   enfj  train
# 4  NaN  one speaking thrive maintain empathetic insigh...   enfj  train
# 5  Vin  glad weak sympathetic aware ignorant one nervo...   istp  train
# 6  Vin  confused stunned hungry grateful thing noble c...   istp   test
# 7  NaN  persuading motivating coworker mission walk en...   enfj  train
# 8  Vin  slow pleased ready careful impressed worried l...   istp  train
# 9  NaN  insight theres sure allow among relationships ...   enfj  train

# %%
df_final_classify_raw.head(10)
# Out:
#   char                                               mods target  split
# 0  NaN  make roles forthright talking rarely strive wi...   enfj   test
# 1  Vin  invincible good amazed certain annoyed interes...   istp  train
# 2  Vin  sure angry certain busy heir worthless certain...   istp  train
# 3  NaN  ones see getting opportunity judging educate f...   enfj   test
# 4  Vin  sure slave sure patient right inexperienced ab...   istp  train
# 5  NaN  ideas motivating relationships voice like sens...   enfj  train
# 6  Vin  confused concerned annoyed able life glad righ...   istp  train
# 7  NaN  problems purpose map strengths coaches humanit...   enfj  train
# 8  Vin  sazed right able able tired quiet worried wron...   istp  train
# 9  NaN  train help sixteen reliable arrows heart using...   enfj    val

# %%
df_final_classyfy_mistTest_p16Train_raw.head(10)
# Out:
#   char                                               mods target split
# 0  Vin  alone right idiot noble stunned afraid certain...   istp  test
# 1  Vin  worried lenient fascinating worthless busy cer...   istp  test
# 2  Vin  one grateful afraid able harsh noble close unp...   istp   val
# 3  Vin  able guest uncomfortable focused alive fine me...   istp   val
# 4  Vin  about glad life glad able wrong shocked sorry ...   istp   val
# 5  Vin  creature certain able sympathetic good happy r...   istp  test
# 6  Vin  thirsty person able wise able able certain diz...   istp  test
# 7  Vin  able hungry sure wrong safe able worried frien...   istp   val
# 8  Vin  able afraid fine ignorant willing heavier able...   istp  test
# 9  Vin  lady certain sure slave sure strong good confu...   istp  test

# %%
### Train, Val & Test: Combined
# X_train = df_final_classify_processed.loc[df_final_classify_processed['split'].isin(["train", "val"]), ["mods"]]
# X_test = df_final_classify_processed.loc[df_final_classify_processed['split'].isin(["test"]), ["mods"]]

# y_train = df_final_classify_processed.loc[df_final_classify_processed['split'].isin(["train", "val"]), ["target"]]
# y_test = df_final_classify_processed.loc[df_final_classify_processed['split'].isin(["test"]), ["target"]]

# X_train = df_final_classify_raw.loc[df_final_classify_raw['split'].isin(["train", "val"]), ["mods"]]
# X_test = df_final_classify_raw.loc[df_final_classify_raw['split'].isin(["test"]), ["mods"]]

# y_train = df_final_classify_raw.loc[df_final_classify_raw['split'].isin(["train", "val"]), ["target"]]
# y_test = df_final_classify_raw.loc[df_final_classify_raw['split'].isin(["test"]), ["target"]]

### Train: P_16 , Val: Mist , Test: Mist ###
# X_train = df_final_classyfy_mistTest_p16Train_raw.loc[df_final_classyfy_mistTest_p16Train_raw['split'].isin(["train", "val"]), ["mods"]]
# X_test = df_final_classyfy_mistTest_p16Train_raw.loc[df_final_classyfy_mistTest_p16Train_raw['split'].isin(["test"]), ["mods"]]

# y_train = df_final_classyfy_mistTest_p16Train_raw.loc[df_final_classyfy_mistTest_p16Train_raw['split'].isin(["train", "val"]), ["target"]]
# y_test = df_final_classyfy_mistTest_p16Train_raw.loc[df_final_classyfy_mistTest_p16Train_raw['split'].isin(["test"]), ["target"]]

### Train: P_16 , Test: Mist ###
X_train = df_final_classyfy_mistTest_p16Train_raw.loc[df_final_classyfy_mistTest_p16Train_raw['split'].isin(["train"]), ["mods"]]
X_test = df_final_classyfy_mistTest_p16Train_raw.loc[df_final_classyfy_mistTest_p16Train_raw['split'].isin(["test", "val"]), ["mods"]]

y_train = df_final_classyfy_mistTest_p16Train_raw.loc[df_final_classyfy_mistTest_p16Train_raw['split'].isin(["train"]), ["target"]]
y_test = df_final_classyfy_mistTest_p16Train_raw.loc[df_final_classyfy_mistTest_p16Train_raw['split'].isin(["test", "val"]), ["target"]]

# %%
X_train = X_train.iloc[:,0]
X_test = X_test.iloc[:,0]

y_train = y_train.iloc[:,0]
y_test = y_test.iloc[:,0]

# %%
print(X_train)
print(y_train)
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {X_test.shape}")
# Out:
# 285     make roles forthright talking rarely strive wi...
# 286     ones see getting opportunity judging educate f...
# 287     ideas motivating relationships voice like sens...
# 288     problems purpose map strengths coaches humanit...
# 289     train help sixteen reliable arrows heart using...
#                               ...
# 1297    scuba examining many bored allow appreciate we...
# 1298    projects way introverted quite easily thinking...
# 1299    five adrenaline sometimes enjoy especially spo...
# 1300    circumstances restlessness paralyzed ones buil...
# 1301    face introverted rules like interest concept a...
# Name: mods, Length: 1017, dtype: object
# 285     enfj
# 286     enfj
# 287     enfj
# 288     enfj
# 289     enfj
#         ...
# 1297    istp
# 1298    istp
# 1299    istp
# 1300    istp
# 1301    istp
# Name: target, Length: 1017, dtype: object
# X_train shape: (1017,)
# y_train shape: (1017,)
# X_test shape: (285,)
# y_test shape: (285,)

# %% [markdown]
# # 🪵🪵 Bag of Words and TF-IDF

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Bag of Words
count_vect = CountVectorizer(tokenizer=casual_tokenize)
X_train_count = count_vect.fit_transform(X_train)
X_test_count = count_vect.transform(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
# print(X_train_count)
# print(X_test_count)
print(f"X_train_count shape: {X_train_count.shape}")
print(f"y_train_count shape: {X_test_count.shape}")
# Out:
# X_train_count shape: (1017, 4114)
# y_train_count shape: (285, 4114)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# TF-IDF
tfidf = TfidfVectorizer(tokenizer=casual_tokenize)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
# print(X_train_tfidf)
# print(X_test_tfidf)
print(f"X_train_tfidf shape: {X_train_tfidf.shape}")
print(f"y_train_tfidf shape: {X_test_tfidf.shape}")
# Out:
# X_train_tfidf shape: (1017, 4114)
# y_train_tfidf shape: (285, 4114)

# %% [markdown]
# # 🚦Classification

# %%
# @title Classify_text_function


from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC, SVC
import numpy as np

def classify_text(X_train, y_train, X_test, y_test, feature_name, vectorizer):

    rf = RandomForestClassifier(random_state=42)
    rf.fit(X_train, y_train)

    lr = LogisticRegression(random_state=42)
    lr.fit(X_train, y_train)

    rf_predictions = rf.predict(X_test)
    lr_predictions = lr.predict(X_test)

    dt = DecisionTreeClassifier(random_state=42)
    dt.fit(X_train, y_train)

    linear_svm = LinearSVC(random_state=42)
    linear_svm.fit(X_train, y_train)

    nonlinear_svm = SVC(random_state=42)
    nonlinear_svm.fit(X_train, y_train)


    models = {
        "RandomForest": rf,
        "Logistic Regression": lr,
        "Decision Tree": dt,
        "Linear SVM": linear_svm,
        "Non-linear SVM": nonlinear_svm
    }

    for model_name, model in models.items():
        predictions = model.predict(X_test_count)
        print(f"Resultados de {model_name} con el texto representado como {feature_name}:")
        # print(f"Labels: {y_test} / Predictions: {predictions}")
        print(classification_report(y_test, predictions))
        print("-" * 60)

    importances = rf.feature_importances_
    feature_names = vectorizer.get_feature_names_out()
    sorted_indices = np.argsort(importances)[::-1]
    print("Top palabras para Random Forest:")
    for i in range(10):
      print(feature_names[sorted_indices[i]], importances[sorted_indices[i]])


    coef = lr.coef_[0]
    sorted_indices = np.argsort(coef)[::-1]
    print("\nTop palabras para Regresión Logística:")
    for i in range(10):
      print(feature_names[sorted_indices[i]], coef[sorted_indices[i]])

# %%
classify_text(X_train_count, y_train, X_test_count, y_test, "CountVectorizer", count_vect)
classify_text(X_train_tfidf, y_train, X_test_tfidf, y_test, "TfidfVectorizer", tfidf)
# Out:
# Resultados de RandomForest con el texto representado como CountVectorizer:
#               precision    recall  f1-score   support
#
#         enfj       0.00      0.00      0.00         3
#         enfp       0.00      0.00      0.00         0
#         entj       0.00      0.00      0.00         7
#         entp       0.15      0.15      0.15        34
#         esfj       0.01      0.10      0.02        10
#         esfp       0.00      0.00      0.00         2
#         estj       0.29      0.29      0.29         7
#         estp       0.00      0.00      0.00         9
#         infj       0.05      0.03      0.04        30
#         infp       0.00      0.00      0.00        52
#         intj       0.00      0.00      0.00         7
#         intp       0.00      0.00      0.00         0
#         isfj       0.00      0.00      0.00         3
#         isfp       0.12      0.14      0.13        14
#         istj       0.10      0.18      0.12        34
# ...
