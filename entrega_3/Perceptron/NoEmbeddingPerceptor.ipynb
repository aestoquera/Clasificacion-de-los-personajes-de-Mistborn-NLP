# %%
#@title 📐Voocabulario { display-mode: "form" }
class Vocabulary(object):
    """Clase para procesar texto y extrar el vocabulario existente para su posterior mapeo.
    """
    def __init__(self, token_to_idx=None, add_unk=True, unk_token=""):
        """
        Args: token_to_idx(dict): Pre existing map of Tokens to Index.
            : add_unk(bool): A flag indicating whether to add UNK Token.
            : unk_token(string): The UNK Token to add in Vocabulary.
        """
        if token_to_idx is None:
            token_to_idx = {}
        self._token_to_idx = token_to_idx
        self._idx_to_token = {idx:token for token,idx in self._token_to_idx.items()}
        self._add_unk = add_unk
        self._unk_token = unk_token
        self.unk_index = -1
        if add_unk:
            self.unk_index = self.add_token(unk_token)

    def add_token(self, token):
        """Update the mapping dictionary based on the Tokens.
        Args: token: The item to add into the Vocabulary.
        Returns: index: Integer corresponding to the Token.
        """
        if token in self._token_to_idx:
            index = self._token_to_idx[token]
        else:
            index = len(self._token_to_idx)
            self._token_to_idx[token] = index
            self._idx_to_token[index] = token
        return index

    def add_many(self, tokens):
        """Add a list of Tokens into Vocabulary.
        Args: tokens(list): A list of string Tokens.
        Returns: indices(list): A list of indices correspoinding to the Tokens.
        """
        return [self.add_token(token) for token in tokens]

    def lookup_token(self, token):
        """Retrieve the Index associated with the Token.
        Args: token(str): The Token to lookup.
        Returns: index(int): The Index correspoinding to the Token.
        """
        if self.unk_index >= 0:
            return self._token_to_idx.get(token, self.unk_index)
        else:
            return self._token_to_idx[token]

    def lookup_index(self, index):
        """Return the Token associated with the Index.
        Args: index(int): The Index to lookup.
        Returns: token(str): The Token correspoinding to the Index.
        """
        if index not in self._idx_to_token:
            raise KeyError(f"the index {index} is not in the Vocabulary")
        return self._idx_to_token[index]

    def __str__(self):
        return "<Vocabulary (size=%d)" % len(self)

    def __len__(self):
        return len(self._token_to_idx)
    def to_serializable(self):
        """ returns a dictionary that can be serialized """
        return {'token_to_idx': self._token_to_idx}

    @classmethod
    def from_serializable(cls, contents):
        """ instantiates the Vocabulary from a serialized dictionary """
        return cls(**contents)

# %%
#@title 📐Review vectorizer{ display-mode: "form" }
#Basado en Rao, D., & McMahan, B. (2019). Natural language processing with PyTorch: build intelligent language applications using deep learning

from collections import Counter
import string
import numpy as np


class Vectorizer(object):
    """The Vectorizer coordinates the Vocabularies and puts them to use.
    """
    def __init__(self, textVocab, personalityVocab):
        """
        Args: textVocab: Maps words to Integers.
            : personalityVocab: Maps class labels to Integers.
        """
        self.textVocab = textVocab
        self.personalityVocab = personalityVocab

    def vectorize(self, modifiers):
        """Create a collasped Onehot Vector for the modifiers.
        Args: modifiers: The modifiers
        Returns: one_hot: The collapsed one hot Encoding.
        """
        one_hot = np.zeros(len(self.textVocab), dtype=np.float32)
        tokens = modifiers.split(" ")
        
        for token in tokens:
            if token not in string.punctuation:
                one_hot[self.textVocab.lookup_token(token)] = 1
        return one_hot

    @classmethod
    def from_dataframe(cls, dataframe, cutoff=0):
        """Instantiate the Vectorizer from DataFrame.
        Args: dataframe(DataFrame): The modifiers Dataset.
            :  cufoff(int): Parameter for frequency based Filtering.
        Returns: An instance of the Vectorizer.
        """
        textVocab = Vocabulary(add_unk=True)
        personalityVocab = Vocabulary(add_unk=False)
        #@ Adding Ratings:
        for rating in (set(dataframe.target)):
            personalityVocab.add_token(rating)
        #@ Adding Topwords if count > provided count:
        word_counts = Counter()
        for modifiers in dataframe.mods:
            for word in modifiers.split(" "):
                if word not in string.punctuation:
                    word_counts[word] += 1
        for word, count in word_counts.items():
            if count > cutoff:
                textVocab.add_token(word)
        print(f"Vocab: {textVocab}")
        return cls(textVocab, personalityVocab)

    def get_vocab(self):
        """Returns the modifiers Vocabulary.
        """
        return (self.textVocab, self.personalityVocab)

# %%
#@title Dataset Manager{ display-mode: "form" }
#Basado en Rao, D., & McMahan, B. (2019). Natural language processing with PyTorch: build intelligent language applications using deep learning

import torch
from torch.utils.data import Dataset
import json
import pandas as pd

class DatasetManager(Dataset):
    def __init__(self, dataframe, vectorizer):
        """
        Args: dataframe(pandas.DataFrame): The dataset.
            : vectorizer(Vectorizer): Vector instantiated from dataset.
        """
        self.dataframe = dataframe
        self._vectorizer = vectorizer

        self.train_df = self.dataframe[self.dataframe.split == "train"]
        self.train_size = len(self.train_df)

        self.val_df = self.dataframe[self.dataframe.split == "val"]
        self.validation_size = len(self.val_df)

        self.test_df = self.dataframe[self.dataframe.split == "test"]
        self.test_size = len(self.test_df)

        

        self._lookup_dict = {"train": (self.train_df, self.train_size),
                                "val": (self.val_df, self.validation_size),
                                "test": (self.test_df, self.test_size)}
        print({"train": self.train_size,
                                "val": self.validation_size,
                                "test": self.test_size})
        # print(f"{self.train_df.head(0)}")
        self.set_split("train")

    @classmethod
    def load_dataset_and_make_vectorizer(cls, review_csv):
        """Load dataset and make new vectorizer from scratch.
        Args: review_csv: Location of the dataset.
        Returns: An instance of ReviewDataset.
        """
        dataframe = pd.read_csv(review_csv)
        dataframe["mods"] = dataframe["mods"].apply(lambda x: x.lower())
        train_dataframe = dataframe[dataframe.split == "train"]
        return cls(dataframe, Vectorizer.from_dataframe(train_dataframe))

    def save_vectorizer(self, vectorizer_filepath):
        with open(vectorizer_filepath, "w") as fp:
            json.dump(self._vectorizer.to_serializable(), fp)

    def get_vectorizer(self):
        """Returns the Vectorizer.
        """
        return self._vectorizer

    def set_split(self, split="train"):
        """Splits the dataset using a column in the DataFrame.
        Args: split(str): One of "train", "val" or "test"
        """
        self._target_split = split
        self._target_df, self._target_size = self._lookup_dict[split]

    def __len__(self):
        return self._target_size

    def __getitem__(self, index):
        """Primary entry point of PyTorch Datasets.
        Args: index: Index of the Datapoint.
        Returns: A dictionary holding the Data point features and labels.
        """
        row = self._target_df.iloc[index]
        modifiedVector = self._vectorizer.vectorize(row.mods)
        targetIndex = self._vectorizer.personalityVocab.lookup_token(row.target)
        return {"x_data": modifiedVector,
                "y_target": targetIndex}

    

    def get_num_batches(self, batch_size):
        """Given a batch size, return the number of batches in the Dataset.
        Args: batch_size(int)
        Returns: Number of batches in the Dataset.
        """
        return len(self) // batch_size

# %%
#@title Batcher Generator{ display-mode: "form" }
import torch
from torch.utils.data import DataLoader

def generate_batches(dataset, batch_size, shuffle=True,
                     drop_last=True, device="cpu"):
  """A generator function which wraps the PyTorch DataLoader.
  """
  dataloader = DataLoader(dataset=dataset, batch_size=batch_size,
                          shuffle=shuffle, drop_last=drop_last)

  for data_dict in dataloader:
    out_data_dict = {}
    for name, tensor in data_dict.items():
      out_data_dict[name] = data_dict[name].to(device)
    yield out_data_dict


def make_train_state(args):
    return {'epoch_index': 0,
            'train_loss': [],
            'train_acc': [],
            'val_loss': [],
            'val_acc': [],
            'test_loss': 1,
            'test_acc': 1,
            'cuda': args.cuda}


def compute_accuracy(y_pred, y_target):
    _, y_pred_indices = y_pred.max(dim=1)
    n_correct = torch.eq(y_pred_indices, y_target).sum().item()
    return n_correct / len(y_pred_indices)

# %% [markdown]
# # Sin W2V

# %% [markdown]
# ## Creación del vocabulario

# %%
URI_DATASET = '../../../Datasets/dataset_clasificador_final/classify_char_raw.csv'
dataset = DatasetManager.load_dataset_and_make_vectorizer(URI_DATASET)
# Out:
# Vocab: <Vocabulary (size=3862)
# {'train': 911, 'val': 195, 'test': 196}

# %% [markdown]
# ## Generar batches

# %%
train_batches = generate_batches(dataset, batch_size=128)

# %% [markdown]
# ## Definición del perceptron

# %%
import torch.nn as nn
import torch.nn.functional as F

class Perceptron(nn.Module):
    def __init__(self, input_size, output_size):
        super().__init__()
        self.linear = nn.Linear(input_size, output_size)
    
    def forward(self, x):
        x = self.linear(x)
        #_, x = torch.max(x, 1)
        return x

# %%
from argparse import Namespace
args = Namespace(
    review_csv=URI_DATASET,
    cuda=True,
    batch_size=16,
    learning_rate=0.001,
    num_epochs=250,
)

# %%
import torch
from torch.utils.data import DataLoader
import torch.optim as optim
import torch.nn as nn

#Creamos el dataset usando el ReviewDataset y el path que tenemos en args.
dataset = DatasetManager.load_dataset_and_make_vectorizer(args.review_csv)
#Creamos un diccionario para ir guardando los valores y loss de cada epoch.
train_state = make_train_state(args)

#Si CUDA no está disponible usamos CPU.
if not torch.cuda.is_available():
    args.cuda = False
args.device = torch.device("cuda" if args.cuda else "cpu")
# Out:
# Vocab: <Vocabulary (size=3862)
# {'train': 911, 'val': 195, 'test': 196}

# %% [markdown]
# ## Training Loop

# %%
import torch
import torch.nn as nn
def train_and_validate(args, classifier, optimizer, criterion, dataset):
    for epoch_index in range(args.num_epochs):
        train_state['epoch_index'] = epoch_index


        # Generamos los training batches con el train set.
        dataset.set_split('train')
        batch_generator = generate_batches(dataset, batch_size=args.batch_size, device=args.device)
        running_loss = 0.0
        running_acc = 0.0
        #Llamamos al método .train() del clasificador para indicar que el modelo está en "modo de entrenamiento" y los parámetros del modelo son mutables.
        classifier.train()
        for batch_index, batch_dict in enumerate(batch_generator):
            # Por cada minibatch ejecutamos la rutina de entrenamiento:
            # step 1. Ponemos a 0 los gradientes
            optimizer.zero_grad()
            # step 2. Calculamos el ouput del clasificador en este paso.
            y_pred = classifier(x=batch_dict['x_data'].float())

            # print(f"Y-pred {y_pred}")
            # print(f"Y-pred shape {y_pred.shape}")
            y_target =  batch_dict['y_target'].long()
            # print(f"Y-target {y_target}")
            # print(f"Y-target shape {y_target.shape}")
            loss = criterion(y_pred,y_target)
            loss_batch = loss.item()
            running_loss += (loss_batch - running_loss) / (batch_index + 1)
            # step 4. Usamos el loss para producir los gradientes.
            loss.backward()
            # step 5.Usamos  el optimizador para dar un paso de gradiente
            optimizer.step()
            # --------------------------------------------------
            #Calculmos el accuracy para tener una métrica extra además del loss.
            acc_batch = compute_accuracy(y_pred, batch_dict['y_target'])
            running_acc += (acc_batch - running_acc) / (batch_index + 1)
        print("Train loss: {:.3f} in Epoch {}".format(running_loss, epoch_index))
        print("Train accuracy: {:.3f} in Epoch {}".format(running_acc, epoch_index))
        train_state['train_loss'].append(running_loss)
        train_state['train_acc'].append(running_acc)
        # Iterate over val dataset

        # setup: batch generator, set loss and acc to 0, set eval mode on
        dataset.set_split('val')
        batch_generator = generate_batches(dataset, batch_size=args.batch_size, device=args.device)
        running_loss = 0.
        running_acc = 0.
        classifier.eval()
        for batch_index, batch_dict in enumerate(batch_generator):
            # step 1. compute the output
            y_pred = classifier(x=batch_dict['x_data'].float())
            # step 2. compute the loss
            loss = criterion(y_pred, batch_dict['y_target'].long())
            loss_batch = loss.item()
            running_loss += (loss_batch - running_loss) / (batch_index + 1)
            # step 3. compute the accuracy
            acc_batch = compute_accuracy(y_pred, batch_dict['y_target'])
            running_acc += (acc_batch - running_acc) / (batch_index + 1)
        print("Val loss: {:.3f} in Epoch {}".format(running_loss, epoch_index))
        print("Val accuracy: {:.3f} in Epoch {}".format(running_acc, epoch_index))
        # print(f"Y pred {y_pred}")
        # print(f"Y real {  batch_dict['y_target']}")
        train_state['val_loss'].append(running_loss)
        train_state['val_acc'].append(running_acc)

    return train_state

def test(args,dataset, classifier, criterion):
    dataset.set_split('test')
    batch_generator = generate_batches(dataset, batch_size=len(dataset), device=args.device)  # Utiliza el tamaño del conjunto de prueba como tamaño de lote
    classifier.eval()  # Pon el modelo en modo de evaluación

    with torch.no_grad():  # Desactiva el cálculo de gradientes durante la evaluación
        for batch_dict in batch_generator:
            # Mueve los datos al dispositivo si es necesario
            x_data = batch_dict['x_data'].float().to(args.device)
            y_target = batch_dict['y_target'].long().to(args.device)

            # step 1. compute the output
            y_pred = classifier(x=x_data)

            # step 2. compute the loss
            loss = criterion(y_pred, y_target)
            running_loss = loss.item()

            # step 3. compute the accuracy
            running_acc = compute_accuracy(y_pred, y_target)

    print("Test loss: {:.3f}".format(running_loss))
    print("Test accuracy: {:.3f}".format(running_acc))

def getMostImportantTokens(classifier, vectorizer):
    # Obtén los pesos de la capa lineal fc1
    fc1_weights = classifier.linear.weight.detach()

    # Número de clases
    num_classes = fc1_weights.size(0)

    # Imprime los valores más característicos para cada clase
    for class_index in range(num_classes):
        class_weights = fc1_weights[class_index]
        _, indices = torch.sort(class_weights, descending=True)
        indices = indices.numpy().tolist()
        class_Name = list(set(dataset.dataframe["target"]))[class_index]
        print(f"\nTop values for Class {class_Name}:")

        for index in indices[:10]:
            index_name = vectorizer.textVocab.lookup_index(index)
            weight_value = class_weights[index].item()
            print(f"· {index_name}: {round(weight_value,3)}")

def trainEvalTestAndAnalyze(dataframeURL):
    # Crear el dataset y el vectorizador
    dataset = DatasetManager.load_dataset_and_make_vectorizer(dataframeURL)
    vectorizer = dataset.get_vectorizer()
    # Crear el clasificador y moverlo al dispositivo adecuado
    print(f"Tamaño red entrada: {len(vectorizer.textVocab)}")
    classifier = Perceptron(input_size=len(vectorizer.textVocab), output_size=16)
    classifier = classifier.to(args.device)
    # Crear el optimizador y la función de pérdida
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(classifier.parameters(), lr=args.learning_rate, momentum=0.9)
    # Entrenar y validar
    train_state = train_and_validate(args, classifier, optimizer, criterion, dataset)
    test(args,dataset, classifier, criterion)
    getMostImportantTokens(classifier, vectorizer)

# %% [markdown]
# ## Analisis

# %%
datasets = ['../../../Datasets/dataset_clasificador_final/classify_char_raw.csv', '../../../Datasets/dataset_clasificador_final/classify_mistTest_p16Train_raw.csv']
for url in datasets:
    print(f"Training with {url[-20:]}")
    trainEvalTestAndAnalyze(url)
    print("........................................................")
# Out:
# Training with lassify_char_raw.csv
# Vocab: <Vocabulary (size=3862)
# {'train': 911, 'val': 195, 'test': 196}
# Tamaño red entrada: 3862
# Train loss: 2.767 in Epoch 0
# Train accuracy: 0.077 in Epoch 0
# Val loss: 2.769 in Epoch 0
# Val accuracy: 0.089 in Epoch 0
# Train loss: 2.743 in Epoch 1
# Train accuracy: 0.151 in Epoch 1
# Val loss: 2.762 in Epoch 1
# Val accuracy: 0.094 in Epoch 1
# Train loss: 2.721 in Epoch 2
# Train accuracy: 0.181 in Epoch 2
# Val loss: 2.753 in Epoch 2
# Val accuracy: 0.099 in Epoch 2
# Train loss: 2.699 in Epoch 3
# Train accuracy: 0.196 in Epoch 3
# Val loss: 2.745 in Epoch 3
# Val accuracy: 0.099 in Epoch 3
# Train loss: 2.676 in Epoch 4
# Train accuracy: 0.209 in Epoch 4
# Val loss: 2.741 in Epoch 4
# Val accuracy: 0.089 in Epoch 4
# Train loss: 2.656 in Epoch 5
# Train accuracy: 0.212 in Epoch 5
# Val loss: 2.732 in Epoch 5
# Val accuracy: 0.089 in Epoch 5
# Train loss: 2.636 in Epoch 6
# Train accuracy: 0.222 in Epoch 6
# Val loss: 2.725 in Epoch 6
# Val accuracy: 0.104 in Epoch 6
# Train loss: 2.616 in Epoch 7
# Train accuracy: 0.234 in Epoch 7
# Val loss: 2.719 in Epoch 7
# Val accuracy: 0.104 in Epoch 7
# Train loss: 2.596 in Epoch 8
# Train accuracy: 0.235 in Epoch 8
# Val loss: 2.714 in Epoch 8
# Val accuracy: 0.109 in Epoch 8
# Train loss: 2.580 in Epoch 9
# Train accuracy: 0.243 in Epoch 9
# Val loss: 2.713 in Epoch 9
# Val accuracy: 0.104 in Epoch 9
# Train loss: 2.561 in Epoch 10
# Train accuracy: 0.249 in Epoch 10
# Val loss: 2.704 in Epoch 10
# Val accuracy: 0.104 in Epoch 10
# Train loss: 2.545 in Epoch 11
# Train accuracy: 0.266 in Epoch 11
# Val loss: 2.699 in Epoch 11
# Val accuracy: 0.104 in Epoch 11
# Train loss: 2.528 in Epoch 12
# Train accuracy: 0.272 in Epoch 12
# Val loss: 2.699 in Epoch 12
# Val accuracy: 0.104 in Epoch 12
# Train loss: 2.513 in Epoch 13
# Train accuracy: 0.292 in Epoch 13
# Val loss: 2.690 in Epoch 13
# Val accuracy: 0.104 in Epoch 13
# Train loss: 2.495 in Epoch 14
# Train accuracy: 0.306 in Epoch 14
# Val loss: 2.684 in Epoch 14
# Val accuracy: 0.109 in Epoch 14
# Train loss: 2.483 in Epoch 15
# Train accuracy: 0.316 in Epoch 15
# Val loss: 2.680 in Epoch 15
# Val accuracy: 0.120 in Epoch 15
# Train loss: 2.466 in Epoch 16
# Train accuracy: 0.348 in Epoch 16
# Val loss: 2.674 in Epoch 16
# Val accuracy: 0.130 in Epoch 16
# Train loss: 2.452 in Epoch 17
# Train accuracy: 0.362 in Epoch 17
# Val loss: 2.677 in Epoch 17
# Val accuracy: 0.120 in Epoch 17
# Train loss: 2.433 in Epoch 18
# Train accuracy: 0.387 in Epoch 18
# Val loss: 2.666 in Epoch 18
# Val accuracy: 0.135 in Epoch 18
# Train loss: 2.422 in Epoch 19
# Train accuracy: 0.403 in Epoch 19
# Val loss: 2.668 in Epoch 19
# Val accuracy: 0.135 in Epoch 19
# Train loss: 2.405 in Epoch 20
# Train accuracy: 0.416 in Epoch 20
# Val loss: 2.660 in Epoch 20
# Val accuracy: 0.141 in Epoch 20
# Train loss: 2.391 in Epoch 21
# Train accuracy: 0.437 in Epoch 21
# Val loss: 2.666 in Epoch 21
# Val accuracy: 0.141 in Epoch 21
# Train loss: 2.377 in Epoch 22
# Train accuracy: 0.459 in Epoch 22
# Val loss: 2.652 in Epoch 22
# Val accuracy: 0.151 in Epoch 22
# Train loss: 2.361 in Epoch 23
# Train accuracy: 0.479 in Epoch 23
# Val loss: 2.655 in Epoch 23
# Val accuracy: 0.146 in Epoch 23
# Train loss: 2.348 in Epoch 24
# Train accuracy: 0.501 in Epoch 24
# Val loss: 2.641 in Epoch 24
# Val accuracy: 0.156 in Epoch 24
# Train loss: 2.334 in Epoch 25
# Train accuracy: 0.516 in Epoch 25
# Val loss: 2.640 in Epoch 25
# Val accuracy: 0.156 in Epoch 25
# Train loss: 2.324 in Epoch 26
# Train accuracy: 0.525 in Epoch 26
# Val loss: 2.637 in Epoch 26
# Val accuracy: 0.167 in Epoch 26
# Train loss: 2.309 in Epoch 27
# Train accuracy: 0.550 in Epoch 27
# Val loss: 2.632 in Epoch 27
# Val accuracy: 0.172 in Epoch 27
# Train loss: 2.297 in Epoch 28
# Train accuracy: 0.578 in Epoch 28
# Val loss: 2.630 in Epoch 28
# Val accuracy: 0.156 in Epoch 28
# Train loss: 2.282 in Epoch 29
# Train accuracy: 0.595 in Epoch 29
# Val loss: 2.628 in Epoch 29
# Val accuracy: 0.151 in Epoch 29
# Train loss: 2.269 in Epoch 30
# Train accuracy: 0.608 in Epoch 30
# Val loss: 2.623 in Epoch 30
# Val accuracy: 0.161 in Epoch 30
# Train loss: 2.257 in Epoch 31
# Train accuracy: 0.626 in Epoch 31
# Val loss: 2.621 in Epoch 31
# Val accuracy: 0.161 in Epoch 31
# Train loss: 2.246 in Epoch 32
# Train accuracy: 0.642 in Epoch 32
# Val loss: 2.615 in Epoch 32
# Val accuracy: 0.167 in Epoch 32
# Train loss: 2.231 in Epoch 33
# Train accuracy: 0.653 in Epoch 33
# Val loss: 2.619 in Epoch 33
# Val accuracy: 0.161 in Epoch 33
# Train loss: 2.219 in Epoch 34
# Train accuracy: 0.673 in Epoch 34
# Val loss: 2.611 in Epoch 34
# Val accuracy: 0.167 in Epoch 34
# Train loss: 2.208 in Epoch 35
# Train accuracy: 0.684 in Epoch 35
# Val loss: 2.608 in Epoch 35
# Val accuracy: 0.161 in Epoch 35
# Train loss: 2.197 in Epoch 36
# Train accuracy: 0.698 in Epoch 36
# Val loss: 2.604 in Epoch 36
# Val accuracy: 0.167 in Epoch 36
# Train loss: 2.182 in Epoch 37
# Train accuracy: 0.709 in Epoch 37
# Val loss: 2.605 in Epoch 37
# Val accuracy: 0.156 in Epoch 37
# Train loss: 2.171 in Epoch 38
# Train accuracy: 0.717 in Epoch 38
# Val loss: 2.596 in Epoch 38
# Val accuracy: 0.167 in Epoch 38
# Train loss: 2.158 in Epoch 39
# Train accuracy: 0.721 in Epoch 39
# Val loss: 2.593 in Epoch 39
# Val accuracy: 0.172 in Epoch 39
# Train loss: 2.149 in Epoch 40
# Train accuracy: 0.737 in Epoch 40
# Val loss: 2.591 in Epoch 40
# Val accuracy: 0.177 in Epoch 40
# Train loss: 2.135 in Epoch 41
# Train accuracy: 0.753 in Epoch 41
# Val loss: 2.592 in Epoch 41
# Val accuracy: 0.177 in Epoch 41
# Train loss: 2.125 in Epoch 42
# Train accuracy: 0.751 in Epoch 42
# Val loss: 2.588 in Epoch 42
# Val accuracy: 0.182 in Epoch 42
# Train loss: 2.114 in Epoch 43
# Train accuracy: 0.760 in Epoch 43
# Val loss: 2.582 in Epoch 43
# Val accuracy: 0.193 in Epoch 43
# Train loss: 2.095 in Epoch 44
# Train accuracy: 0.772 in Epoch 44
# Val loss: 2.579 in Epoch 44
# Val accuracy: 0.203 in Epoch 44
# Train loss: 2.091 in Epoch 45
# Train accuracy: 0.777 in Epoch 45
# Val loss: 2.575 in Epoch 45
# Val accuracy: 0.203 in Epoch 45
# Train loss: 2.075 in Epoch 46
# Train accuracy: 0.782 in Epoch 46
# Val loss: 2.578 in Epoch 46
# Val accuracy: 0.198 in Epoch 46
# Train loss: 2.067 in Epoch 47
# Train accuracy: 0.796 in Epoch 47
# Val loss: 2.577 in Epoch 47
# Val accuracy: 0.203 in Epoch 47
# Train loss: 2.054 in Epoch 48
# Train accuracy: 0.797 in Epoch 48
# Val loss: 2.566 in Epoch 48
# Val accuracy: 0.214 in Epoch 48
# Train loss: 2.046 in Epoch 49
# Train accuracy: 0.799 in Epoch 49
# Val loss: 2.563 in Epoch 49
# Val accuracy: 0.214 in Epoch 49
# Train loss: 2.028 in Epoch 50
# Train accuracy: 0.815 in Epoch 50
# Val loss: 2.561 in Epoch 50
# Val accuracy: 0.219 in Epoch 50
# Train loss: 2.023 in Epoch 51
# Train accuracy: 0.821 in Epoch 51
# Val loss: 2.560 in Epoch 51
# Val accuracy: 0.224 in Epoch 51
# Train loss: 2.007 in Epoch 52
# Train accuracy: 0.826 in Epoch 52
# Val loss: 2.554 in Epoch 52
# Val accuracy: 0.214 in Epoch 52
# Train loss: 1.996 in Epoch 53
# Train accuracy: 0.833 in Epoch 53
# Val loss: 2.557 in Epoch 53
# Val accuracy: 0.229 in Epoch 53
# Train loss: 1.986 in Epoch 54
# Train accuracy: 0.842 in Epoch 54
# Val loss: 2.557 in Epoch 54
# Val accuracy: 0.229 in Epoch 54
# Train loss: 1.978 in Epoch 55
# Train accuracy: 0.846 in Epoch 55
# Val loss: 2.550 in Epoch 55
# Val accuracy: 0.234 in Epoch 55
# Train loss: 1.964 in Epoch 56
# Train accuracy: 0.852 in Epoch 56
# Val loss: 2.556 in Epoch 56
# Val accuracy: 0.234 in Epoch 56
# Train loss: 1.952 in Epoch 57
# Train accuracy: 0.853 in Epoch 57
# Val loss: 2.549 in Epoch 57
# Val accuracy: 0.250 in Epoch 57
# Train loss: 1.940 in Epoch 58
# Train accuracy: 0.853 in Epoch 58
# Val loss: 2.540 in Epoch 58
# Val accuracy: 0.245 in Epoch 58
# Train loss: 1.931 in Epoch 59
# Train accuracy: 0.859 in Epoch 59
# Val loss: 2.537 in Epoch 59
# Val accuracy: 0.240 in Epoch 59
# Train loss: 1.923 in Epoch 60
# Train accuracy: 0.863 in Epoch 60
# Val loss: 2.534 in Epoch 60
# Val accuracy: 0.240 in Epoch 60
# Train loss: 1.913 in Epoch 61
# Train accuracy: 0.863 in Epoch 61
# Val loss: 2.532 in Epoch 61
# Val accuracy: 0.245 in Epoch 61
# Train loss: 1.901 in Epoch 62
# Train accuracy: 0.873 in Epoch 62
# Val loss: 2.548 in Epoch 62
# Val accuracy: 0.234 in Epoch 62
# Train loss: 1.890 in Epoch 63
# Train accuracy: 0.873 in Epoch 63
# Val loss: 2.529 in Epoch 63
# Val accuracy: 0.240 in Epoch 63
# Train loss: 1.880 in Epoch 64
# Train accuracy: 0.873 in Epoch 64
# Val loss: 2.523 in Epoch 64
# Val accuracy: 0.240 in Epoch 64
# Train loss: 1.871 in Epoch 65
# Train accuracy: 0.875 in Epoch 65
# Val loss: 2.521 in Epoch 65
# Val accuracy: 0.240 in Epoch 65
# Train loss: 1.861 in Epoch 66
# Train accuracy: 0.884 in Epoch 66
# Val loss: 2.520 in Epoch 66
# Val accuracy: 0.240 in Epoch 66
# Train loss: 1.849 in Epoch 67
# Train accuracy: 0.884 in Epoch 67
# Val loss: 2.518 in Epoch 67
# Val accuracy: 0.245 in Epoch 67
# Train loss: 1.839 in Epoch 68
# Train accuracy: 0.886 in Epoch 68
# Val loss: 2.518 in Epoch 68
# Val accuracy: 0.245 in Epoch 68
# Train loss: 1.830 in Epoch 69
# Train accuracy: 0.888 in Epoch 69
# Val loss: 2.510 in Epoch 69
# Val accuracy: 0.240 in Epoch 69
# Train loss: 1.817 in Epoch 70
# Train accuracy: 0.894 in Epoch 70
# Val loss: 2.515 in Epoch 70
# Val accuracy: 0.240 in Epoch 70
# Train loss: 1.809 in Epoch 71
# Train accuracy: 0.894 in Epoch 71
# Val loss: 2.514 in Epoch 71
# Val accuracy: 0.234 in Epoch 71
# Train loss: 1.802 in Epoch 72
# Train accuracy: 0.894 in Epoch 72
# Val loss: 2.508 in Epoch 72
# Val accuracy: 0.240 in Epoch 72
# Train loss: 1.790 in Epoch 73
# Train accuracy: 0.895 in Epoch 73
# Val loss: 2.506 in Epoch 73
# Val accuracy: 0.240 in Epoch 73
# Train loss: 1.785 in Epoch 74
# Train accuracy: 0.896 in Epoch 74
# Val loss: 2.509 in Epoch 74
# Val accuracy: 0.240 in Epoch 74
# Train loss: 1.772 in Epoch 75
# Train accuracy: 0.897 in Epoch 75
# Val loss: 2.496 in Epoch 75
# Val accuracy: 0.245 in Epoch 75
# Train loss: 1.767 in Epoch 76
# Train accuracy: 0.898 in Epoch 76
# Val loss: 2.501 in Epoch 76
# Val accuracy: 0.245 in Epoch 76
# Train loss: 1.752 in Epoch 77
# Train accuracy: 0.901 in Epoch 77
# Val loss: 2.496 in Epoch 77
# Val accuracy: 0.245 in Epoch 77
# Train loss: 1.745 in Epoch 78
# Train accuracy: 0.903 in Epoch 78
# Val loss: 2.494 in Epoch 78
# Val accuracy: 0.250 in Epoch 78
# Train loss: 1.736 in Epoch 79
# Train accuracy: 0.905 in Epoch 79
# Val loss: 2.490 in Epoch 79
# Val accuracy: 0.250 in Epoch 79
# Train loss: 1.725 in Epoch 80
# Train accuracy: 0.908 in Epoch 80
# Val loss: 2.492 in Epoch 80
# Val accuracy: 0.245 in Epoch 80
# Train loss: 1.714 in Epoch 81
# Train accuracy: 0.911 in Epoch 81
# Val loss: 2.494 in Epoch 81
# Val accuracy: 0.250 in Epoch 81
# Train loss: 1.710 in Epoch 82
# Train accuracy: 0.915 in Epoch 82
# Val loss: 2.506 in Epoch 82
# Val accuracy: 0.245 in Epoch 82
# Train loss: 1.698 in Epoch 83
# Train accuracy: 0.917 in Epoch 83
# Val loss: 2.492 in Epoch 83
# Val accuracy: 0.250 in Epoch 83
# Train loss: 1.691 in Epoch 84
# Train accuracy: 0.917 in Epoch 84
# Val loss: 2.478 in Epoch 84
# Val accuracy: 0.260 in Epoch 84
# Train loss: 1.681 in Epoch 85
# Train accuracy: 0.920 in Epoch 85
# Val loss: 2.477 in Epoch 85
# Val accuracy: 0.260 in Epoch 85
# Train loss: 1.675 in Epoch 86
# Train accuracy: 0.920 in Epoch 86
# Val loss: 2.481 in Epoch 86
# Val accuracy: 0.250 in Epoch 86
# Train loss: 1.664 in Epoch 87
# Train accuracy: 0.920 in Epoch 87
# Val loss: 2.478 in Epoch 87
# Val accuracy: 0.255 in Epoch 87
# Train loss: 1.653 in Epoch 88
# Train accuracy: 0.922 in Epoch 88
# Val loss: 2.473 in Epoch 88
# Val accuracy: 0.260 in Epoch 88
# Train loss: 1.645 in Epoch 89
# Train accuracy: 0.921 in Epoch 89
# Val loss: 2.470 in Epoch 89
# Val accuracy: 0.255 in Epoch 89
# Train loss: 1.634 in Epoch 90
# Train accuracy: 0.922 in Epoch 90
# Val loss: 2.473 in Epoch 90
# Val accuracy: 0.255 in Epoch 90
# Train loss: 1.625 in Epoch 91
# Train accuracy: 0.924 in Epoch 91
# Val loss: 2.471 in Epoch 91
# Val accuracy: 0.271 in Epoch 91
# Train loss: 1.617 in Epoch 92
# Train accuracy: 0.922 in Epoch 92
# Val loss: 2.466 in Epoch 92
# Val accuracy: 0.271 in Epoch 92
# Train loss: 1.608 in Epoch 93
# Train accuracy: 0.926 in Epoch 93
# Val loss: 2.466 in Epoch 93
# Val accuracy: 0.271 in Epoch 93
# Train loss: 1.601 in Epoch 94
# Train accuracy: 0.929 in Epoch 94
# Val loss: 2.465 in Epoch 94
# Val accuracy: 0.266 in Epoch 94
# Train loss: 1.592 in Epoch 95
# Train accuracy: 0.933 in Epoch 95
# Val loss: 2.460 in Epoch 95
# Val accuracy: 0.271 in Epoch 95
# Train loss: 1.584 in Epoch 96
# Train accuracy: 0.936 in Epoch 96
# Val loss: 2.459 in Epoch 96
# Val accuracy: 0.271 in Epoch 96
# Train loss: 1.575 in Epoch 97
# Train accuracy: 0.938 in Epoch 97
# Val loss: 2.455 in Epoch 97
# Val accuracy: 0.271 in Epoch 97
# Train loss: 1.565 in Epoch 98
# Train accuracy: 0.939 in Epoch 98
# Val loss: 2.452 in Epoch 98
# Val accuracy: 0.276 in Epoch 98
# Train loss: 1.559 in Epoch 99
# Train accuracy: 0.939 in Epoch 99
# Val loss: 2.454 in Epoch 99
# Val accuracy: 0.276 in Epoch 99
# Train loss: 1.549 in Epoch 100
# Train accuracy: 0.941 in Epoch 100
# Val loss: 2.451 in Epoch 100
# Val accuracy: 0.276 in Epoch 100
# Train loss: 1.540 in Epoch 101
# Train accuracy: 0.942 in Epoch 101
# Val loss: 2.449 in Epoch 101
# Val accuracy: 0.281 in Epoch 101
# Train loss: 1.535 in Epoch 102
# Train accuracy: 0.941 in Epoch 102
# Val loss: 2.449 in Epoch 102
# Val accuracy: 0.281 in Epoch 102
# Train loss: 1.529 in Epoch 103
# Train accuracy: 0.941 in Epoch 103
# Val loss: 2.447 in Epoch 103
# Val accuracy: 0.281 in Epoch 103
# Train loss: 1.518 in Epoch 104
# Train accuracy: 0.943 in Epoch 104
# Val loss: 2.447 in Epoch 104
# Val accuracy: 0.276 in Epoch 104
# Train loss: 1.511 in Epoch 105
# Train accuracy: 0.949 in Epoch 105
# Val loss: 2.443 in Epoch 105
# Val accuracy: 0.271 in Epoch 105
# Train loss: 1.503 in Epoch 106
# Train accuracy: 0.946 in Epoch 106
# Val loss: 2.448 in Epoch 106
# Val accuracy: 0.276 in Epoch 106
# Train loss: 1.497 in Epoch 107
# Train accuracy: 0.946 in Epoch 107
# Val loss: 2.436 in Epoch 107
# Val accuracy: 0.286 in Epoch 107
# Train loss: 1.485 in Epoch 108
# Train accuracy: 0.948 in Epoch 108
# Val loss: 2.437 in Epoch 108
# Val accuracy: 0.286 in Epoch 108
# Train loss: 1.483 in Epoch 109
# Train accuracy: 0.948 in Epoch 109
# Val loss: 2.434 in Epoch 109
# Val accuracy: 0.286 in Epoch 109
# Train loss: 1.473 in Epoch 110
# Train accuracy: 0.948 in Epoch 110
# Val loss: 2.447 in Epoch 110
# Val accuracy: 0.271 in Epoch 110
# Train loss: 1.463 in Epoch 111
# Train accuracy: 0.949 in Epoch 111
# Val loss: 2.429 in Epoch 111
# Val accuracy: 0.286 in Epoch 111
# Train loss: 1.454 in Epoch 112
# Train accuracy: 0.950 in Epoch 112
# Val loss: 2.434 in Epoch 112
# Val accuracy: 0.281 in Epoch 112
# Train loss: 1.450 in Epoch 113
# Train accuracy: 0.951 in Epoch 113
# Val loss: 2.422 in Epoch 113
# Val accuracy: 0.281 in Epoch 113
# Train loss: 1.440 in Epoch 114
# Train accuracy: 0.952 in Epoch 114
# Val loss: 2.438 in Epoch 114
# Val accuracy: 0.271 in Epoch 114
# Train loss: 1.436 in Epoch 115
# Train accuracy: 0.952 in Epoch 115
# Val loss: 2.428 in Epoch 115
# Val accuracy: 0.281 in Epoch 115
# Train loss: 1.428 in Epoch 116
# Train accuracy: 0.953 in Epoch 116
# Val loss: 2.422 in Epoch 116
# Val accuracy: 0.276 in Epoch 116
# Train loss: 1.422 in Epoch 117
# Train accuracy: 0.954 in Epoch 117
# Val loss: 2.430 in Epoch 117
# Val accuracy: 0.276 in Epoch 117
# Train loss: 1.413 in Epoch 118
# Train accuracy: 0.956 in Epoch 118
# Val loss: 2.424 in Epoch 118
# Val accuracy: 0.271 in Epoch 118
# Train loss: 1.403 in Epoch 119
# Train accuracy: 0.958 in Epoch 119
# Val loss: 2.426 in Epoch 119
# Val accuracy: 0.276 in Epoch 119
# Train loss: 1.397 in Epoch 120
# Train accuracy: 0.958 in Epoch 120
# Val loss: 2.420 in Epoch 120
# Val accuracy: 0.281 in Epoch 120
# Train loss: 1.391 in Epoch 121
# Train accuracy: 0.959 in Epoch 121
# Val loss: 2.425 in Epoch 121
# Val accuracy: 0.276 in Epoch 121
# Train loss: 1.381 in Epoch 122
# Train accuracy: 0.959 in Epoch 122
# Val loss: 2.418 in Epoch 122
# Val accuracy: 0.281 in Epoch 122
# Train loss: 1.375 in Epoch 123
# Train accuracy: 0.959 in Epoch 123
# Val loss: 2.412 in Epoch 123
# Val accuracy: 0.286 in Epoch 123
# Train loss: 1.366 in Epoch 124
# Train accuracy: 0.961 in Epoch 124
# Val loss: 2.414 in Epoch 124
# Val accuracy: 0.281 in Epoch 124
# Train loss: 1.361 in Epoch 125
# Train accuracy: 0.960 in Epoch 125
# Val loss: 2.412 in Epoch 125
# Val accuracy: 0.281 in Epoch 125
# Train loss: 1.354 in Epoch 126
# Train accuracy: 0.962 in Epoch 126
# Val loss: 2.405 in Epoch 126
# Val accuracy: 0.281 in Epoch 126
# Train loss: 1.348 in Epoch 127
# Train accuracy: 0.961 in Epoch 127
# Val loss: 2.404 in Epoch 127
# Val accuracy: 0.281 in Epoch 127
# Train loss: 1.338 in Epoch 128
# Train accuracy: 0.962 in Epoch 128
# Val loss: 2.404 in Epoch 128
# Val accuracy: 0.281 in Epoch 128
# Train loss: 1.335 in Epoch 129
# Train accuracy: 0.962 in Epoch 129
# Val loss: 2.401 in Epoch 129
# Val accuracy: 0.286 in Epoch 129
# Train loss: 1.326 in Epoch 130
# Train accuracy: 0.961 in Epoch 130
# Val loss: 2.407 in Epoch 130
# Val accuracy: 0.281 in Epoch 130
# Train loss: 1.319 in Epoch 131
# Train accuracy: 0.961 in Epoch 131
# Val loss: 2.408 in Epoch 131
# Val accuracy: 0.276 in Epoch 131
# Train loss: 1.309 in Epoch 132
# Train accuracy: 0.962 in Epoch 132
# Val loss: 2.409 in Epoch 132
# Val accuracy: 0.276 in Epoch 132
# Train loss: 1.305 in Epoch 133
# Train accuracy: 0.962 in Epoch 133
# Val loss: 2.401 in Epoch 133
# Val accuracy: 0.276 in Epoch 133
# Train loss: 1.301 in Epoch 134
# Train accuracy: 0.963 in Epoch 134
# Val loss: 2.394 in Epoch 134
# Val accuracy: 0.281 in Epoch 134
# Train loss: 1.292 in Epoch 135
# Train accuracy: 0.962 in Epoch 135
# Val loss: 2.389 in Epoch 135
# Val accuracy: 0.281 in Epoch 135
# Train loss: 1.287 in Epoch 136
# Train accuracy: 0.962 in Epoch 136
# Val loss: 2.393 in Epoch 136
# Val accuracy: 0.281 in Epoch 136
# Train loss: 1.280 in Epoch 137
# Train accuracy: 0.962 in Epoch 137
# Val loss: 2.394 in Epoch 137
# Val accuracy: 0.281 in Epoch 137
# Train loss: 1.274 in Epoch 138
# Train accuracy: 0.962 in Epoch 138
# Val loss: 2.389 in Epoch 138
# Val accuracy: 0.286 in Epoch 138
# Train loss: 1.267 in Epoch 139
# Train accuracy: 0.962 in Epoch 139
# Val loss: 2.401 in Epoch 139
# Val accuracy: 0.271 in Epoch 139
# Train loss: 1.262 in Epoch 140
# Train accuracy: 0.964 in Epoch 140
# Val loss: 2.383 in Epoch 140
# Val accuracy: 0.281 in Epoch 140
# Train loss: 1.254 in Epoch 141
# Train accuracy: 0.963 in Epoch 141
# Val loss: 2.400 in Epoch 141
# Val accuracy: 0.260 in Epoch 141
# Train loss: 1.247 in Epoch 142
# Train accuracy: 0.965 in Epoch 142
# Val loss: 2.379 in Epoch 142
# Val accuracy: 0.281 in Epoch 142
# Train loss: 1.242 in Epoch 143
# Train accuracy: 0.963 in Epoch 143
# Val loss: 2.383 in Epoch 143
# Val accuracy: 0.271 in Epoch 143
# Train loss: 1.237 in Epoch 144
# Train accuracy: 0.963 in Epoch 144
# Val loss: 2.378 in Epoch 144
# Val accuracy: 0.281 in Epoch 144
# Train loss: 1.229 in Epoch 145
# Train accuracy: 0.963 in Epoch 145
# Val loss: 2.379 in Epoch 145
# Val accuracy: 0.276 in Epoch 145
# Train loss: 1.222 in Epoch 146
# Train accuracy: 0.965 in Epoch 146
# Val loss: 2.376 in Epoch 146
# Val accuracy: 0.281 in Epoch 146
# Train loss: 1.216 in Epoch 147
# Train accuracy: 0.965 in Epoch 147
# Val loss: 2.375 in Epoch 147
# Val accuracy: 0.276 in Epoch 147
# Train loss: 1.213 in Epoch 148
# Train accuracy: 0.968 in Epoch 148
# Val loss: 2.380 in Epoch 148
# Val accuracy: 0.276 in Epoch 148
# Train loss: 1.206 in Epoch 149
# Train accuracy: 0.967 in Epoch 149
# Val loss: 2.382 in Epoch 149
# Val accuracy: 0.276 in Epoch 149
# Train loss: 1.197 in Epoch 150
# Train accuracy: 0.968 in Epoch 150
# Val loss: 2.371 in Epoch 150
# Val accuracy: 0.276 in Epoch 150
# Train loss: 1.191 in Epoch 151
# Train accuracy: 0.967 in Epoch 151
# Val loss: 2.374 in Epoch 151
# Val accuracy: 0.271 in Epoch 151
# Train loss: 1.188 in Epoch 152
# Train accuracy: 0.967 in Epoch 152
# Val loss: 2.382 in Epoch 152
# Val accuracy: 0.266 in Epoch 152
# Train loss: 1.177 in Epoch 153
# Train accuracy: 0.968 in Epoch 153
# Val loss: 2.376 in Epoch 153
# Val accuracy: 0.276 in Epoch 153
# Train loss: 1.175 in Epoch 154
# Train accuracy: 0.967 in Epoch 154
# Val loss: 2.370 in Epoch 154
# Val accuracy: 0.276 in Epoch 154
# Train loss: 1.169 in Epoch 155
# Train accuracy: 0.967 in Epoch 155
# Val loss: 2.367 in Epoch 155
# Val accuracy: 0.276 in Epoch 155
# Train loss: 1.164 in Epoch 156
# Train accuracy: 0.968 in Epoch 156
# Val loss: 2.375 in Epoch 156
# Val accuracy: 0.271 in Epoch 156
# Train loss: 1.161 in Epoch 157
# Train accuracy: 0.967 in Epoch 157
# Val loss: 2.376 in Epoch 157
# Val accuracy: 0.271 in Epoch 157
# Train loss: 1.149 in Epoch 158
# Train accuracy: 0.969 in Epoch 158
# Val loss: 2.374 in Epoch 158
# Val accuracy: 0.266 in Epoch 158
# Train loss: 1.148 in Epoch 159
# Train accuracy: 0.967 in Epoch 159
# Val loss: 2.371 in Epoch 159
# Val accuracy: 0.266 in Epoch 159
# Train loss: 1.139 in Epoch 160
# Train accuracy: 0.970 in Epoch 160
# Val loss: 2.366 in Epoch 160
# Val accuracy: 0.281 in Epoch 160
# Train loss: 1.135 in Epoch 161
# Train accuracy: 0.970 in Epoch 161
# Val loss: 2.360 in Epoch 161
# Val accuracy: 0.276 in Epoch 161
# Train loss: 1.129 in Epoch 162
# Train accuracy: 0.970 in Epoch 162
# Val loss: 2.369 in Epoch 162
# Val accuracy: 0.276 in Epoch 162
# Train loss: 1.125 in Epoch 163
# Train accuracy: 0.971 in Epoch 163
# Val loss: 2.367 in Epoch 163
# Val accuracy: 0.276 in Epoch 163
# Train loss: 1.120 in Epoch 164
# Train accuracy: 0.973 in Epoch 164
# Val loss: 2.350 in Epoch 164
# Val accuracy: 0.281 in Epoch 164
# Train loss: 1.113 in Epoch 165
# Train accuracy: 0.973 in Epoch 165
# Val loss: 2.358 in Epoch 165
# Val accuracy: 0.276 in Epoch 165
# Train loss: 1.109 in Epoch 166
# Train accuracy: 0.972 in Epoch 166
# Val loss: 2.360 in Epoch 166
# Val accuracy: 0.281 in Epoch 166
# Train loss: 1.101 in Epoch 167
# Train accuracy: 0.972 in Epoch 167
# Val loss: 2.356 in Epoch 167
# Val accuracy: 0.276 in Epoch 167
# Train loss: 1.101 in Epoch 168
# Train accuracy: 0.973 in Epoch 168
# Val loss: 2.364 in Epoch 168
# Val accuracy: 0.276 in Epoch 168
# Train loss: 1.090 in Epoch 169
# Train accuracy: 0.974 in Epoch 169
# Val loss: 2.343 in Epoch 169
# Val accuracy: 0.281 in Epoch 169
# Train loss: 1.086 in Epoch 170
# Train accuracy: 0.973 in Epoch 170
# Val loss: 2.358 in Epoch 170
# Val accuracy: 0.276 in Epoch 170
# Train loss: 1.081 in Epoch 171
# Train accuracy: 0.973 in Epoch 171
# Val loss: 2.353 in Epoch 171
# Val accuracy: 0.276 in Epoch 171
# Train loss: 1.075 in Epoch 172
# Train accuracy: 0.973 in Epoch 172
# Val loss: 2.349 in Epoch 172
# Val accuracy: 0.276 in Epoch 172
# Train loss: 1.071 in Epoch 173
# Train accuracy: 0.973 in Epoch 173
# Val loss: 2.363 in Epoch 173
# Val accuracy: 0.266 in Epoch 173
# Train loss: 1.064 in Epoch 174
# Train accuracy: 0.977 in Epoch 174
# Val loss: 2.344 in Epoch 174
# Val accuracy: 0.276 in Epoch 174
# Train loss: 1.061 in Epoch 175
# Train accuracy: 0.975 in Epoch 175
# Val loss: 2.342 in Epoch 175
# Val accuracy: 0.281 in Epoch 175
# Train loss: 1.059 in Epoch 176
# Train accuracy: 0.975 in Epoch 176
# Val loss: 2.350 in Epoch 176
# Val accuracy: 0.276 in Epoch 176
# Train loss: 1.050 in Epoch 177
# Train accuracy: 0.975 in Epoch 177
# Val loss: 2.340 in Epoch 177
# Val accuracy: 0.286 in Epoch 177
# Train loss: 1.047 in Epoch 178
# Train accuracy: 0.975 in Epoch 178
# Val loss: 2.344 in Epoch 178
# Val accuracy: 0.281 in Epoch 178
# Train loss: 1.041 in Epoch 179
# Train accuracy: 0.977 in Epoch 179
# Val loss: 2.341 in Epoch 179
# Val accuracy: 0.281 in Epoch 179
# Train loss: 1.036 in Epoch 180
# Train accuracy: 0.977 in Epoch 180
# Val loss: 2.340 in Epoch 180
# Val accuracy: 0.286 in Epoch 180
# Train loss: 1.028 in Epoch 181
# Train accuracy: 0.979 in Epoch 181
# Val loss: 2.339 in Epoch 181
# Val accuracy: 0.286 in Epoch 181
# Train loss: 1.025 in Epoch 182
# Train accuracy: 0.978 in Epoch 182
# Val loss: 2.347 in Epoch 182
# Val accuracy: 0.281 in Epoch 182
# Train loss: 1.021 in Epoch 183
# Train accuracy: 0.978 in Epoch 183
# Val loss: 2.345 in Epoch 183
# Val accuracy: 0.276 in Epoch 183
# Train loss: 1.013 in Epoch 184
# Train accuracy: 0.979 in Epoch 184
# Val loss: 2.343 in Epoch 184
# Val accuracy: 0.281 in Epoch 184
# Train loss: 1.012 in Epoch 185
# Train accuracy: 0.979 in Epoch 185
# Val loss: 2.337 in Epoch 185
# Val accuracy: 0.281 in Epoch 185
# Train loss: 1.009 in Epoch 186
# Train accuracy: 0.978 in Epoch 186
# Val loss: 2.337 in Epoch 186
# Val accuracy: 0.281 in Epoch 186
# Train loss: 1.003 in Epoch 187
# Train accuracy: 0.978 in Epoch 187
# Val loss: 2.336 in Epoch 187
# Val accuracy: 0.286 in Epoch 187
# Train loss: 0.999 in Epoch 188
# Train accuracy: 0.978 in Epoch 188
# Val loss: 2.328 in Epoch 188
# Val accuracy: 0.281 in Epoch 188
# Train loss: 0.988 in Epoch 189
# Train accuracy: 0.980 in Epoch 189
# Val loss: 2.329 in Epoch 189
# Val accuracy: 0.286 in Epoch 189
# Train loss: 0.986 in Epoch 190
# Train accuracy: 0.978 in Epoch 190
# Val loss: 2.349 in Epoch 190
# Val accuracy: 0.271 in Epoch 190
# Train loss: 0.983 in Epoch 191
# Train accuracy: 0.978 in Epoch 191
# Val loss: 2.328 in Epoch 191
# Val accuracy: 0.281 in Epoch 191
# Train loss: 0.979 in Epoch 192
# Train accuracy: 0.979 in Epoch 192
# Val loss: 2.337 in Epoch 192
# Val accuracy: 0.281 in Epoch 192
# Train loss: 0.971 in Epoch 193
# Train accuracy: 0.978 in Epoch 193
# Val loss: 2.327 in Epoch 193
# Val accuracy: 0.281 in Epoch 193
# Train loss: 0.967 in Epoch 194
# Train accuracy: 0.978 in Epoch 194
# Val loss: 2.337 in Epoch 194
# Val accuracy: 0.281 in Epoch 194
# Train loss: 0.962 in Epoch 195
# Train accuracy: 0.978 in Epoch 195
# Val loss: 2.329 in Epoch 195
# Val accuracy: 0.286 in Epoch 195
# Train loss: 0.960 in Epoch 196
# Train accuracy: 0.980 in Epoch 196
# Val loss: 2.324 in Epoch 196
# Val accuracy: 0.286 in Epoch 196
# Train loss: 0.957 in Epoch 197
# Train accuracy: 0.981 in Epoch 197
# Val loss: 2.321 in Epoch 197
# Val accuracy: 0.286 in Epoch 197
# Train loss: 0.950 in Epoch 198
# Train accuracy: 0.981 in Epoch 198
# Val loss: 2.326 in Epoch 198
# Val accuracy: 0.286 in Epoch 198
# Train loss: 0.948 in Epoch 199
# Train accuracy: 0.981 in Epoch 199
# Val loss: 2.332 in Epoch 199
# Val accuracy: 0.276 in Epoch 199
# Train loss: 0.942 in Epoch 200
# Train accuracy: 0.981 in Epoch 200
# Val loss: 2.321 in Epoch 200
# Val accuracy: 0.281 in Epoch 200
# Train loss: 0.938 in Epoch 201
# Train accuracy: 0.980 in Epoch 201
# Val loss: 2.331 in Epoch 201
# Val accuracy: 0.281 in Epoch 201
# Train loss: 0.935 in Epoch 202
# Train accuracy: 0.980 in Epoch 202
# Val loss: 2.321 in Epoch 202
# Val accuracy: 0.286 in Epoch 202
# Train loss: 0.930 in Epoch 203
# Train accuracy: 0.981 in Epoch 203
# Val loss: 2.324 in Epoch 203
# Val accuracy: 0.281 in Epoch 203
# Train loss: 0.927 in Epoch 204
# Train accuracy: 0.981 in Epoch 204
# Val loss: 2.322 in Epoch 204
# Val accuracy: 0.286 in Epoch 204
# Train loss: 0.922 in Epoch 205
# Train accuracy: 0.981 in Epoch 205
# Val loss: 2.315 in Epoch 205
# Val accuracy: 0.286 in Epoch 205
# Train loss: 0.916 in Epoch 206
# Train accuracy: 0.982 in Epoch 206
# Val loss: 2.336 in Epoch 206
# Val accuracy: 0.276 in Epoch 206
# Train loss: 0.912 in Epoch 207
# Train accuracy: 0.981 in Epoch 207
# Val loss: 2.319 in Epoch 207
# Val accuracy: 0.292 in Epoch 207
# Train loss: 0.910 in Epoch 208
# Train accuracy: 0.982 in Epoch 208
# Val loss: 2.312 in Epoch 208
# Val accuracy: 0.292 in Epoch 208
# Train loss: 0.903 in Epoch 209
# Train accuracy: 0.983 in Epoch 209
# Val loss: 2.310 in Epoch 209
# Val accuracy: 0.286 in Epoch 209
# Train loss: 0.902 in Epoch 210
# Train accuracy: 0.982 in Epoch 210
# Val loss: 2.334 in Epoch 210
# Val accuracy: 0.281 in Epoch 210
# Train loss: 0.897 in Epoch 211
# Train accuracy: 0.982 in Epoch 211
# Val loss: 2.315 in Epoch 211
# Val accuracy: 0.286 in Epoch 211
# Train loss: 0.891 in Epoch 212
# Train accuracy: 0.984 in Epoch 212
# Val loss: 2.324 in Epoch 212
# Val accuracy: 0.281 in Epoch 212
# Train loss: 0.888 in Epoch 213
# Train accuracy: 0.983 in Epoch 213
# Val loss: 2.309 in Epoch 213
# Val accuracy: 0.292 in Epoch 213
# Train loss: 0.885 in Epoch 214
# Train accuracy: 0.983 in Epoch 214
# Val loss: 2.318 in Epoch 214
# Val accuracy: 0.292 in Epoch 214
# Train loss: 0.880 in Epoch 215
# Train accuracy: 0.982 in Epoch 215
# Val loss: 2.317 in Epoch 215
# Val accuracy: 0.292 in Epoch 215
# Train loss: 0.878 in Epoch 216
# Train accuracy: 0.982 in Epoch 216
# Val loss: 2.324 in Epoch 216
# Val accuracy: 0.292 in Epoch 216
# Train loss: 0.870 in Epoch 217
# Train accuracy: 0.982 in Epoch 217
# Val loss: 2.310 in Epoch 217
# Val accuracy: 0.297 in Epoch 217
# Train loss: 0.867 in Epoch 218
# Train accuracy: 0.982 in Epoch 218
# Val loss: 2.307 in Epoch 218
# Val accuracy: 0.297 in Epoch 218
# Train loss: 0.864 in Epoch 219
# Train accuracy: 0.982 in Epoch 219
# Val loss: 2.305 in Epoch 219
# Val accuracy: 0.297 in Epoch 219
# Train loss: 0.861 in Epoch 220
# Train accuracy: 0.982 in Epoch 220
# Val loss: 2.306 in Epoch 220
# Val accuracy: 0.297 in Epoch 220
# Train loss: 0.859 in Epoch 221
# Train accuracy: 0.982 in Epoch 221
# Val loss: 2.312 in Epoch 221
# Val accuracy: 0.297 in Epoch 221
# Train loss: 0.851 in Epoch 222
# Train accuracy: 0.983 in Epoch 222
# Val loss: 2.311 in Epoch 222
# Val accuracy: 0.297 in Epoch 222
# Train loss: 0.848 in Epoch 223
# Train accuracy: 0.982 in Epoch 223
# Val loss: 2.297 in Epoch 223
# Val accuracy: 0.302 in Epoch 223
# Train loss: 0.844 in Epoch 224
# Train accuracy: 0.983 in Epoch 224
# Val loss: 2.316 in Epoch 224
# Val accuracy: 0.292 in Epoch 224
# Train loss: 0.844 in Epoch 225
# Train accuracy: 0.982 in Epoch 225
# Val loss: 2.299 in Epoch 225
# Val accuracy: 0.297 in Epoch 225
# Train loss: 0.836 in Epoch 226
# Train accuracy: 0.982 in Epoch 226
# Val loss: 2.307 in Epoch 226
# Val accuracy: 0.292 in Epoch 226
# Train loss: 0.833 in Epoch 227
# Train accuracy: 0.982 in Epoch 227
# Val loss: 2.297 in Epoch 227
# Val accuracy: 0.302 in Epoch 227
# Train loss: 0.833 in Epoch 228
# Train accuracy: 0.982 in Epoch 228
# Val loss: 2.300 in Epoch 228
# Val accuracy: 0.302 in Epoch 228
# Train loss: 0.829 in Epoch 229
# Train accuracy: 0.982 in Epoch 229
# Val loss: 2.294 in Epoch 229
# Val accuracy: 0.302 in Epoch 229
# Train loss: 0.825 in Epoch 230
# Train accuracy: 0.982 in Epoch 230
# Val loss: 2.298 in Epoch 230
# Val accuracy: 0.302 in Epoch 230
# Train loss: 0.820 in Epoch 231
# Train accuracy: 0.982 in Epoch 231
# Val loss: 2.305 in Epoch 231
# Val accuracy: 0.292 in Epoch 231
# Train loss: 0.818 in Epoch 232
# Train accuracy: 0.982 in Epoch 232
# Val loss: 2.304 in Epoch 232
# Val accuracy: 0.297 in Epoch 232
# Train loss: 0.814 in Epoch 233
# Train accuracy: 0.983 in Epoch 233
# Val loss: 2.289 in Epoch 233
# Val accuracy: 0.302 in Epoch 233
# Train loss: 0.809 in Epoch 234
# Train accuracy: 0.983 in Epoch 234
# Val loss: 2.291 in Epoch 234
# Val accuracy: 0.302 in Epoch 234
# Train loss: 0.805 in Epoch 235
# Train accuracy: 0.983 in Epoch 235
# Val loss: 2.295 in Epoch 235
# Val accuracy: 0.297 in Epoch 235
# Train loss: 0.800 in Epoch 236
# Train accuracy: 0.984 in Epoch 236
# Val loss: 2.306 in Epoch 236
# Val accuracy: 0.292 in Epoch 236
# Train loss: 0.798 in Epoch 237
# Train accuracy: 0.984 in Epoch 237
# Val loss: 2.293 in Epoch 237
# Val accuracy: 0.297 in Epoch 237
# Train loss: 0.791 in Epoch 238
# Train accuracy: 0.984 in Epoch 238
# Val loss: 2.294 in Epoch 238
# Val accuracy: 0.292 in Epoch 238
# Train loss: 0.794 in Epoch 239
# Train accuracy: 0.983 in Epoch 239
# Val loss: 2.299 in Epoch 239
# Val accuracy: 0.297 in Epoch 239
# Train loss: 0.790 in Epoch 240
# Train accuracy: 0.983 in Epoch 240
# Val loss: 2.306 in Epoch 240
# Val accuracy: 0.292 in Epoch 240
# Train loss: 0.786 in Epoch 241
# Train accuracy: 0.983 in Epoch 241
# Val loss: 2.298 in Epoch 241
# Val accuracy: 0.297 in Epoch 241
# Train loss: 0.782 in Epoch 242
# Train accuracy: 0.983 in Epoch 242
# Val loss: 2.290 in Epoch 242
# Val accuracy: 0.302 in Epoch 242
# Train loss: 0.779 in Epoch 243
# Train accuracy: 0.984 in Epoch 243
# Val loss: 2.292 in Epoch 243
# Val accuracy: 0.297 in Epoch 243
# Train loss: 0.775 in Epoch 244
# Train accuracy: 0.983 in Epoch 244
# Val loss: 2.299 in Epoch 244
# Val accuracy: 0.292 in Epoch 244
# Train loss: 0.773 in Epoch 245
# Train accuracy: 0.983 in Epoch 245
# Val loss: 2.302 in Epoch 245
# Val accuracy: 0.292 in Epoch 245
# Train loss: 0.768 in Epoch 246
# Train accuracy: 0.984 in Epoch 246
# Val loss: 2.289 in Epoch 246
# Val accuracy: 0.302 in Epoch 246
# Train loss: 0.766 in Epoch 247
# Train accuracy: 0.984 in Epoch 247
# Val loss: 2.293 in Epoch 247
# Val accuracy: 0.302 in Epoch 247
# Train loss: 0.762 in Epoch 248
# Train accuracy: 0.984 in Epoch 248
# Val loss: 2.276 in Epoch 248
# Val accuracy: 0.302 in Epoch 248
# Train loss: 0.758 in Epoch 249
# Train accuracy: 0.984 in Epoch 249
# Val loss: 2.290 in Epoch 249
# Val accuracy: 0.297 in Epoch 249
# Test loss: 2.185
# Test accuracy: 0.342
#
# Top values for Class enfp:
# · imagination: 0.495
# · life: 0.449
# · enthusiasm: 0.436
# · ideas: 0.413
# · imaginative: 0.403
# · create: 0.384
# · creative: 0.379
# · conversations: 0.339
# · dreams: 0.323
# · listening: 0.317
#
# Top values for Class infp:
# · king: 1.079
# · person: 0.578
# · scholar: 0.577
# · man: 0.57
# · sure: 0.525
# · feel: 0.493
# · heir: 0.49
# · happy: 0.446
# · creative: 0.437
# · imaginative: 0.412
#
# Top values for Class enfj:
# · result: 0.392
# · persuading: 0.372
# · needs: 0.36
# · making: 0.358
# · thrive: 0.358
# · come: 0.355
# · relationships: 0.343
# · whats: 0.329
# · rarely: 0.323
# · times: 0.318
#
# Top values for Class esfj:
# · social: 0.887
# · strong: 0.586
# · good: 0.543
# · order: 0.465
# · practical: 0.413
# · help: 0.378
# · take: 0.374
# · loved: 0.372
# · effort: 0.366
# · behavior: 0.358
#
# Top values for Class istp:
# · certain: 0.787
# · tired: 0.771
# · mechanical: 0.729
# · able: 0.607
# · practical: 0.575
# · alive: 0.531
# · surprised: 0.522
# · hands: 0.515
# · insensitive: 0.513
# · good: 0.483
#
# Top values for Class istj:
# · man: 0.654
# · kandra: 0.622
# · clever: 0.477
# · happy: 0.443
# · careful: 0.438
# · work: 0.427
# · dead: 0.409
# · integrity: 0.392
# · old: 0.374
# · speak: 0.369
#
# Top values for Class estj:
# · authority: 0.541
# · way: 0.53
# · work: 0.521
# · respect: 0.487
# · organization: 0.458
# · charge: 0.426
# · well: 0.423
# · hard: 0.407
# · order: 0.398
# · responsibility: 0.382
#
# Top values for Class isfj:
# · hardworking: 0.527
# · relationships: 0.499
# · giving: 0.449
# · loyalty: 0.445
# · needs: 0.432
# · established: 0.421
# · gifts: 0.371
# · devoted: 0.358
# · scenes: 0.357
# · done: 0.357
#
# Top values for Class esfp:
# · time: 0.549
# · moment: 0.471
# · practical: 0.439
# · things: 0.389
# · love: 0.38
# · plan: 0.342
# · attention: 0.332
# · new: 0.328
# · never: 0.322
# · engaging: 0.318
#
# Top values for Class intj:
# · thinking: 0.482
# · applying: 0.463
# · logical: 0.404
# · independent: 0.383
# · systems: 0.378
# · insane: 0.368
# · challenges: 0.36
# · less: 0.355
# · insight: 0.338
# · nature: 0.315
#
# Top values for Class infj:
# · certain: 0.805
# · purpose: 0.664
# · better: 0.523
# · steward: 0.493
# · life: 0.491
# · rebel: 0.458
# · right: 0.456
# · ability: 0.449
# · values: 0.425
# · deep: 0.408
#
# Top values for Class isfp:
# · moment: 0.592
# · present: 0.568
# · artistic: 0.536
# · beauty: 0.52
# · quiet: 0.451
# · experiences: 0.419
# · planning: 0.398
# · able: 0.392
# · spontaneous: 0.386
# · capable: 0.37
#
# Top values for Class entp:
# · ideas: 0.649
# · idea: 0.597
# · visionary: 0.588
# · serious: 0.58
# · success: 0.494
# · worried: 0.467
# · skaa: 0.413
# · mental: 0.408
# · one: 0.399
# · kind: 0.384
#
# Top values for Class entj:
# · strategic: 0.561
# · achieve: 0.486
# · goals: 0.464
# · stronger: 0.456
# · father: 0.422
# · leaders: 0.421
# · results: 0.415
# · make: 0.413
# · rationalism: 0.351
# · fine: 0.346
#
# Top values for Class intp:
# · thought: 0.594
# · ideas: 0.519
# · get: 0.497
# · reason: 0.456
# · understanding: 0.425
# · things: 0.419
# · theories: 0.366
# · might: 0.339
# · mysteries: 0.337
# · logical: 0.336
#
# Top values for Class estp:
# · physical: 0.502
# · energy: 0.461
# · use: 0.406
# · process: 0.399
# · perceptive: 0.398
# · emotional: 0.384
# · go: 0.382
# · observation: 0.365
# · action: 0.353
# · blunt: 0.347
# ........................................................
# Training with est_p16Train_raw.csv
# Vocab: <Vocabulary (size=4115)
# {'train': 1017, 'val': 142, 'test': 143}
# Tamaño red entrada: 4115
# Train loss: 2.775 in Epoch 0
# Train accuracy: 0.055 in Epoch 0
# Val loss: 2.773 in Epoch 0
# Val accuracy: 0.078 in Epoch 0
# Train loss: 2.760 in Epoch 1
# Train accuracy: 0.109 in Epoch 1
# Val loss: 2.772 in Epoch 1
# Val accuracy: 0.086 in Epoch 1
# Train loss: 2.745 in Epoch 2
# Train accuracy: 0.188 in Epoch 2
# Val loss: 2.771 in Epoch 2
# Val accuracy: 0.094 in Epoch 2
# Train loss: 2.730 in Epoch 3
# Train accuracy: 0.271 in Epoch 3
# Val loss: 2.768 in Epoch 3
# Val accuracy: 0.109 in Epoch 3
# Train loss: 2.716 in Epoch 4
# Train accuracy: 0.355 in Epoch 4
# Val loss: 2.770 in Epoch 4
# Val accuracy: 0.070 in Epoch 4
# Train loss: 2.701 in Epoch 5
# Train accuracy: 0.440 in Epoch 5
# Val loss: 2.766 in Epoch 5
# Val accuracy: 0.086 in Epoch 5
# Train loss: 2.686 in Epoch 6
# Train accuracy: 0.515 in Epoch 6
# Val loss: 2.766 in Epoch 6
# Val accuracy: 0.086 in Epoch 6
# Train loss: 2.672 in Epoch 7
# Train accuracy: 0.574 in Epoch 7
# Val loss: 2.766 in Epoch 7
# Val accuracy: 0.070 in Epoch 7
# Train loss: 2.658 in Epoch 8
# Train accuracy: 0.616 in Epoch 8
# Val loss: 2.764 in Epoch 8
# Val accuracy: 0.078 in Epoch 8
# Train loss: 2.643 in Epoch 9
# Train accuracy: 0.668 in Epoch 9
# Val loss: 2.762 in Epoch 9
# Val accuracy: 0.078 in Epoch 9
# Train loss: 2.629 in Epoch 10
# Train accuracy: 0.708 in Epoch 10
# Val loss: 2.764 in Epoch 10
# Val accuracy: 0.055 in Epoch 10
# Train loss: 2.614 in Epoch 11
# Train accuracy: 0.737 in Epoch 11
# Val loss: 2.762 in Epoch 11
# Val accuracy: 0.078 in Epoch 11
# Train loss: 2.600 in Epoch 12
# Train accuracy: 0.760 in Epoch 12
# Val loss: 2.761 in Epoch 12
# Val accuracy: 0.086 in Epoch 12
# Train loss: 2.586 in Epoch 13
# Train accuracy: 0.768 in Epoch 13
# Val loss: 2.762 in Epoch 13
# Val accuracy: 0.062 in Epoch 13
# Train loss: 2.572 in Epoch 14
# Train accuracy: 0.796 in Epoch 14
# Val loss: 2.759 in Epoch 14
# Val accuracy: 0.078 in Epoch 14
# Train loss: 2.558 in Epoch 15
# Train accuracy: 0.815 in Epoch 15
# Val loss: 2.759 in Epoch 15
# Val accuracy: 0.070 in Epoch 15
# Train loss: 2.544 in Epoch 16
# Train accuracy: 0.826 in Epoch 16
# Val loss: 2.760 in Epoch 16
# Val accuracy: 0.070 in Epoch 16
# Train loss: 2.530 in Epoch 17
# Train accuracy: 0.836 in Epoch 17
# Val loss: 2.760 in Epoch 17
# Val accuracy: 0.062 in Epoch 17
# Train loss: 2.516 in Epoch 18
# Train accuracy: 0.851 in Epoch 18
# Val loss: 2.758 in Epoch 18
# Val accuracy: 0.062 in Epoch 18
# Train loss: 2.503 in Epoch 19
# Train accuracy: 0.861 in Epoch 19
# Val loss: 2.757 in Epoch 19
# Val accuracy: 0.055 in Epoch 19
# Train loss: 2.489 in Epoch 20
# Train accuracy: 0.867 in Epoch 20
# Val loss: 2.757 in Epoch 20
# Val accuracy: 0.047 in Epoch 20
# Train loss: 2.475 in Epoch 21
# Train accuracy: 0.869 in Epoch 21
# Val loss: 2.758 in Epoch 21
# Val accuracy: 0.055 in Epoch 21
# Train loss: 2.462 in Epoch 22
# Train accuracy: 0.879 in Epoch 22
# Val loss: 2.756 in Epoch 22
# Val accuracy: 0.055 in Epoch 22
# Train loss: 2.449 in Epoch 23
# Train accuracy: 0.882 in Epoch 23
# Val loss: 2.760 in Epoch 23
# Val accuracy: 0.047 in Epoch 23
# Train loss: 2.435 in Epoch 24
# Train accuracy: 0.889 in Epoch 24
# Val loss: 2.758 in Epoch 24
# Val accuracy: 0.039 in Epoch 24
# Train loss: 2.422 in Epoch 25
# Train accuracy: 0.890 in Epoch 25
# Val loss: 2.761 in Epoch 25
# Val accuracy: 0.039 in Epoch 25
# Train loss: 2.407 in Epoch 26
# Train accuracy: 0.896 in Epoch 26
# Val loss: 2.756 in Epoch 26
# Val accuracy: 0.039 in Epoch 26
# Train loss: 2.395 in Epoch 27
# Train accuracy: 0.902 in Epoch 27
# Val loss: 2.760 in Epoch 27
# Val accuracy: 0.039 in Epoch 27
# Train loss: 2.382 in Epoch 28
# Train accuracy: 0.912 in Epoch 28
# Val loss: 2.758 in Epoch 28
# Val accuracy: 0.039 in Epoch 28
# Train loss: 2.368 in Epoch 29
# Train accuracy: 0.913 in Epoch 29
# Val loss: 2.758 in Epoch 29
# Val accuracy: 0.039 in Epoch 29
# Train loss: 2.355 in Epoch 30
# Train accuracy: 0.919 in Epoch 30
# Val loss: 2.755 in Epoch 30
# Val accuracy: 0.047 in Epoch 30
# Train loss: 2.342 in Epoch 31
# Train accuracy: 0.919 in Epoch 31
# Val loss: 2.757 in Epoch 31
# Val accuracy: 0.047 in Epoch 31
# Train loss: 2.331 in Epoch 32
# Train accuracy: 0.923 in Epoch 32
# Val loss: 2.757 in Epoch 32
# Val accuracy: 0.047 in Epoch 32
# Train loss: 2.317 in Epoch 33
# Train accuracy: 0.922 in Epoch 33
# Val loss: 2.753 in Epoch 33
# Val accuracy: 0.047 in Epoch 33
# Train loss: 2.304 in Epoch 34
# Train accuracy: 0.928 in Epoch 34
# Val loss: 2.758 in Epoch 34
# Val accuracy: 0.039 in Epoch 34
# Train loss: 2.292 in Epoch 35
# Train accuracy: 0.929 in Epoch 35
# Val loss: 2.756 in Epoch 35
# Val accuracy: 0.047 in Epoch 35
# Train loss: 2.278 in Epoch 36
# Train accuracy: 0.935 in Epoch 36
# Val loss: 2.754 in Epoch 36
# Val accuracy: 0.047 in Epoch 36
# Train loss: 2.266 in Epoch 37
# Train accuracy: 0.938 in Epoch 37
# Val loss: 2.757 in Epoch 37
# Val accuracy: 0.047 in Epoch 37
# Train loss: 2.253 in Epoch 38
# Train accuracy: 0.938 in Epoch 38
# Val loss: 2.761 in Epoch 38
# Val accuracy: 0.047 in Epoch 38
# Train loss: 2.241 in Epoch 39
# Train accuracy: 0.939 in Epoch 39
# Val loss: 2.758 in Epoch 39
# Val accuracy: 0.047 in Epoch 39
# Train loss: 2.229 in Epoch 40
# Train accuracy: 0.946 in Epoch 40
# Val loss: 2.757 in Epoch 40
# Val accuracy: 0.039 in Epoch 40
# Train loss: 2.216 in Epoch 41
# Train accuracy: 0.946 in Epoch 41
# Val loss: 2.761 in Epoch 41
# Val accuracy: 0.031 in Epoch 41
# Train loss: 2.203 in Epoch 42
# Train accuracy: 0.953 in Epoch 42
# Val loss: 2.759 in Epoch 42
# Val accuracy: 0.031 in Epoch 42
# Train loss: 2.191 in Epoch 43
# Train accuracy: 0.949 in Epoch 43
# Val loss: 2.763 in Epoch 43
# Val accuracy: 0.023 in Epoch 43
# Train loss: 2.180 in Epoch 44
# Train accuracy: 0.951 in Epoch 44
# Val loss: 2.756 in Epoch 44
# Val accuracy: 0.031 in Epoch 44
# Train loss: 2.167 in Epoch 45
# Train accuracy: 0.953 in Epoch 45
# Val loss: 2.758 in Epoch 45
# Val accuracy: 0.039 in Epoch 45
# Train loss: 2.155 in Epoch 46
# Train accuracy: 0.952 in Epoch 46
# Val loss: 2.759 in Epoch 46
# Val accuracy: 0.031 in Epoch 46
# Train loss: 2.143 in Epoch 47
# Train accuracy: 0.957 in Epoch 47
# Val loss: 2.754 in Epoch 47
# Val accuracy: 0.031 in Epoch 47
# Train loss: 2.130 in Epoch 48
# Train accuracy: 0.957 in Epoch 48
# Val loss: 2.759 in Epoch 48
# Val accuracy: 0.031 in Epoch 48
# Train loss: 2.118 in Epoch 49
# Train accuracy: 0.957 in Epoch 49
# Val loss: 2.757 in Epoch 49
# Val accuracy: 0.039 in Epoch 49
# Train loss: 2.108 in Epoch 50
# Train accuracy: 0.958 in Epoch 50
# Val loss: 2.760 in Epoch 50
# Val accuracy: 0.031 in Epoch 50
# Train loss: 2.096 in Epoch 51
# Train accuracy: 0.962 in Epoch 51
# Val loss: 2.756 in Epoch 51
# Val accuracy: 0.039 in Epoch 51
# Train loss: 2.084 in Epoch 52
# Train accuracy: 0.960 in Epoch 52
# Val loss: 2.761 in Epoch 52
# Val accuracy: 0.039 in Epoch 52
# Train loss: 2.072 in Epoch 53
# Train accuracy: 0.961 in Epoch 53
# Val loss: 2.765 in Epoch 53
# Val accuracy: 0.031 in Epoch 53
# Train loss: 2.060 in Epoch 54
# Train accuracy: 0.963 in Epoch 54
# Val loss: 2.757 in Epoch 54
# Val accuracy: 0.039 in Epoch 54
# Train loss: 2.048 in Epoch 55
# Train accuracy: 0.964 in Epoch 55
# Val loss: 2.765 in Epoch 55
# Val accuracy: 0.039 in Epoch 55
# Train loss: 2.038 in Epoch 56
# Train accuracy: 0.967 in Epoch 56
# Val loss: 2.769 in Epoch 56
# Val accuracy: 0.031 in Epoch 56
# Train loss: 2.027 in Epoch 57
# Train accuracy: 0.965 in Epoch 57
# Val loss: 2.763 in Epoch 57
# Val accuracy: 0.031 in Epoch 57
# Train loss: 2.014 in Epoch 58
# Train accuracy: 0.964 in Epoch 58
# Val loss: 2.761 in Epoch 58
# Val accuracy: 0.039 in Epoch 58
# Train loss: 2.004 in Epoch 59
# Train accuracy: 0.966 in Epoch 59
# Val loss: 2.764 in Epoch 59
# Val accuracy: 0.047 in Epoch 59
# Train loss: 1.992 in Epoch 60
# Train accuracy: 0.966 in Epoch 60
# Val loss: 2.767 in Epoch 60
# Val accuracy: 0.031 in Epoch 60
# Train loss: 1.980 in Epoch 61
# Train accuracy: 0.968 in Epoch 61
# Val loss: 2.764 in Epoch 61
# Val accuracy: 0.039 in Epoch 61
# Train loss: 1.971 in Epoch 62
# Train accuracy: 0.967 in Epoch 62
# Val loss: 2.762 in Epoch 62
# Val accuracy: 0.039 in Epoch 62
# Train loss: 1.960 in Epoch 63
# Train accuracy: 0.970 in Epoch 63
# Val loss: 2.770 in Epoch 63
# Val accuracy: 0.023 in Epoch 63
# Train loss: 1.947 in Epoch 64
# Train accuracy: 0.970 in Epoch 64
# Val loss: 2.764 in Epoch 64
# Val accuracy: 0.039 in Epoch 64
# Train loss: 1.938 in Epoch 65
# Train accuracy: 0.969 in Epoch 65
# Val loss: 2.767 in Epoch 65
# Val accuracy: 0.039 in Epoch 65
# Train loss: 1.926 in Epoch 66
# Train accuracy: 0.970 in Epoch 66
# Val loss: 2.764 in Epoch 66
# Val accuracy: 0.039 in Epoch 66
# Train loss: 1.916 in Epoch 67
# Train accuracy: 0.970 in Epoch 67
# Val loss: 2.767 in Epoch 67
# Val accuracy: 0.031 in Epoch 67
# Train loss: 1.905 in Epoch 68
# Train accuracy: 0.970 in Epoch 68
# Val loss: 2.768 in Epoch 68
# Val accuracy: 0.031 in Epoch 68
# Train loss: 1.894 in Epoch 69
# Train accuracy: 0.973 in Epoch 69
# Val loss: 2.759 in Epoch 69
# Val accuracy: 0.047 in Epoch 69
# Train loss: 1.884 in Epoch 70
# Train accuracy: 0.973 in Epoch 70
# Val loss: 2.759 in Epoch 70
# Val accuracy: 0.047 in Epoch 70
# Train loss: 1.873 in Epoch 71
# Train accuracy: 0.974 in Epoch 71
# Val loss: 2.758 in Epoch 71
# Val accuracy: 0.047 in Epoch 71
# Train loss: 1.863 in Epoch 72
# Train accuracy: 0.975 in Epoch 72
# Val loss: 2.762 in Epoch 72
# Val accuracy: 0.047 in Epoch 72
# Train loss: 1.852 in Epoch 73
# Train accuracy: 0.975 in Epoch 73
# Val loss: 2.763 in Epoch 73
# Val accuracy: 0.047 in Epoch 73
# Train loss: 1.842 in Epoch 74
# Train accuracy: 0.975 in Epoch 74
# Val loss: 2.758 in Epoch 74
# Val accuracy: 0.047 in Epoch 74
# Train loss: 1.831 in Epoch 75
# Train accuracy: 0.975 in Epoch 75
# Val loss: 2.763 in Epoch 75
# Val accuracy: 0.047 in Epoch 75
# Train loss: 1.821 in Epoch 76
# Train accuracy: 0.977 in Epoch 76
# Val loss: 2.768 in Epoch 76
# Val accuracy: 0.039 in Epoch 76
# Train loss: 1.810 in Epoch 77
# Train accuracy: 0.979 in Epoch 77
# Val loss: 2.771 in Epoch 77
# Val accuracy: 0.047 in Epoch 77
# Train loss: 1.800 in Epoch 78
# Train accuracy: 0.979 in Epoch 78
# Val loss: 2.767 in Epoch 78
# Val accuracy: 0.047 in Epoch 78
# Train loss: 1.792 in Epoch 79
# Train accuracy: 0.978 in Epoch 79
# Val loss: 2.768 in Epoch 79
# Val accuracy: 0.047 in Epoch 79
# Train loss: 1.782 in Epoch 80
# Train accuracy: 0.980 in Epoch 80
# Val loss: 2.764 in Epoch 80
# Val accuracy: 0.039 in Epoch 80
# Train loss: 1.772 in Epoch 81
# Train accuracy: 0.981 in Epoch 81
# Val loss: 2.766 in Epoch 81
# Val accuracy: 0.039 in Epoch 81
# Train loss: 1.761 in Epoch 82
# Train accuracy: 0.982 in Epoch 82
# Val loss: 2.764 in Epoch 82
# Val accuracy: 0.047 in Epoch 82
# Train loss: 1.752 in Epoch 83
# Train accuracy: 0.983 in Epoch 83
# Val loss: 2.762 in Epoch 83
# Val accuracy: 0.047 in Epoch 83
# Train loss: 1.742 in Epoch 84
# Train accuracy: 0.983 in Epoch 84
# Val loss: 2.768 in Epoch 84
# Val accuracy: 0.039 in Epoch 84
# Train loss: 1.732 in Epoch 85
# Train accuracy: 0.983 in Epoch 85
# Val loss: 2.760 in Epoch 85
# Val accuracy: 0.039 in Epoch 85
# Train loss: 1.722 in Epoch 86
# Train accuracy: 0.984 in Epoch 86
# Val loss: 2.776 in Epoch 86
# Val accuracy: 0.047 in Epoch 86
# Train loss: 1.713 in Epoch 87
# Train accuracy: 0.983 in Epoch 87
# Val loss: 2.780 in Epoch 87
# Val accuracy: 0.039 in Epoch 87
# Train loss: 1.703 in Epoch 88
# Train accuracy: 0.984 in Epoch 88
# Val loss: 2.772 in Epoch 88
# Val accuracy: 0.047 in Epoch 88
# Train loss: 1.694 in Epoch 89
# Train accuracy: 0.984 in Epoch 89
# Val loss: 2.779 in Epoch 89
# Val accuracy: 0.047 in Epoch 89
# Train loss: 1.684 in Epoch 90
# Train accuracy: 0.985 in Epoch 90
# Val loss: 2.776 in Epoch 90
# Val accuracy: 0.047 in Epoch 90
# Train loss: 1.675 in Epoch 91
# Train accuracy: 0.984 in Epoch 91
# Val loss: 2.764 in Epoch 91
# Val accuracy: 0.047 in Epoch 91
# Train loss: 1.667 in Epoch 92
# Train accuracy: 0.984 in Epoch 92
# Val loss: 2.769 in Epoch 92
# Val accuracy: 0.055 in Epoch 92
# Train loss: 1.657 in Epoch 93
# Train accuracy: 0.984 in Epoch 93
# Val loss: 2.778 in Epoch 93
# Val accuracy: 0.047 in Epoch 93
# Train loss: 1.646 in Epoch 94
# Train accuracy: 0.985 in Epoch 94
# Val loss: 2.779 in Epoch 94
# Val accuracy: 0.039 in Epoch 94
# Train loss: 1.639 in Epoch 95
# Train accuracy: 0.984 in Epoch 95
# Val loss: 2.777 in Epoch 95
# Val accuracy: 0.047 in Epoch 95
# Train loss: 1.631 in Epoch 96
# Train accuracy: 0.984 in Epoch 96
# Val loss: 2.766 in Epoch 96
# Val accuracy: 0.055 in Epoch 96
# Train loss: 1.620 in Epoch 97
# Train accuracy: 0.985 in Epoch 97
# Val loss: 2.763 in Epoch 97
# Val accuracy: 0.047 in Epoch 97
# Train loss: 1.612 in Epoch 98
# Train accuracy: 0.984 in Epoch 98
# Val loss: 2.775 in Epoch 98
# Val accuracy: 0.047 in Epoch 98
# Train loss: 1.603 in Epoch 99
# Train accuracy: 0.984 in Epoch 99
# Val loss: 2.768 in Epoch 99
# Val accuracy: 0.055 in Epoch 99
# Train loss: 1.593 in Epoch 100
# Train accuracy: 0.984 in Epoch 100
# Val loss: 2.776 in Epoch 100
# Val accuracy: 0.047 in Epoch 100
# Train loss: 1.585 in Epoch 101
# Train accuracy: 0.984 in Epoch 101
# Val loss: 2.773 in Epoch 101
# Val accuracy: 0.047 in Epoch 101
# Train loss: 1.577 in Epoch 102
# Train accuracy: 0.985 in Epoch 102
# Val loss: 2.779 in Epoch 102
# Val accuracy: 0.055 in Epoch 102
# Train loss: 1.569 in Epoch 103
# Train accuracy: 0.985 in Epoch 103
# Val loss: 2.779 in Epoch 103
# Val accuracy: 0.039 in Epoch 103
# Train loss: 1.559 in Epoch 104
# Train accuracy: 0.986 in Epoch 104
# Val loss: 2.788 in Epoch 104
# ...
# Train loss: 1.218 in Epoch 150
# Train accuracy: 0.992 in Epoch 150
# Val loss: 2.782 in Epoch 150
# Val accuracy: 0.055 in Epoch 150
# Train loss: 1.213 in Epoch 151
# Train accuracy: 0.993 in Epoch 151
# Val loss: 2.789 in Epoch 151
# Val accuracy: 0.055 in Epoch 151
# Train loss: 1.208 in Epoch 152
# Train accuracy: 0.993 in Epoch 152
# Val loss: 2.791 in Epoch 152
# Val accuracy: 0.055 in Epoch 152
# Train loss: 1.200 in Epoch 153
# Train accuracy: 0.993 in Epoch 153
# Val loss: 2.794 in Epoch 153
# Val accuracy: 0.047 in Epoch 153
# Train loss: 1.195 in Epoch 154
# Train accuracy: 0.993 in Epoch 154
# Val loss: 2.805 in Epoch 154
# Val accuracy: 0.039 in Epoch 154
# Train loss: 1.189 in Epoch 155
# Train accuracy: 0.993 in Epoch 155
# Val loss: 2.800 in Epoch 155
# Val accuracy: 0.039 in Epoch 155
# Train loss: 1.182 in Epoch 156
# Train accuracy: 0.993 in Epoch 156
# Val loss: 2.799 in Epoch 156
# Val accuracy: 0.047 in Epoch 156
# Train loss: 1.176 in Epoch 157
# Train accuracy: 0.993 in Epoch 157
# Val loss: 2.797 in Epoch 157
# Val accuracy: 0.047 in Epoch 157
# Train loss: 1.170 in Epoch 158
# Train accuracy: 0.993 in Epoch 158
# Val loss: 2.811 in Epoch 158
# Val accuracy: 0.047 in Epoch 158
# Train loss: 1.167 in Epoch 159
# Train accuracy: 0.993 in Epoch 159
# Val loss: 2.812 in Epoch 159
# Val accuracy: 0.047 in Epoch 159
# Train loss: 1.158 in Epoch 160
# Train accuracy: 0.993 in Epoch 160
# Val loss: 2.794 in Epoch 160
# Val accuracy: 0.055 in Epoch 160
# Train loss: 1.153 in Epoch 161
# Train accuracy: 0.993 in Epoch 161
# Val loss: 2.789 in Epoch 161
# Val accuracy: 0.055 in Epoch 161
# Train loss: 1.147 in Epoch 162
# Train accuracy: 0.993 in Epoch 162
# Val loss: 2.807 in Epoch 162
# Val accuracy: 0.062 in Epoch 162
# Train loss: 1.141 in Epoch 163
# Train accuracy: 0.993 in Epoch 163
# Val loss: 2.800 in Epoch 163
# Val accuracy: 0.062 in Epoch 163
# Train loss: 1.134 in Epoch 164
# Train accuracy: 0.993 in Epoch 164
# Val loss: 2.796 in Epoch 164
# Val accuracy: 0.062 in Epoch 164
# Train loss: 1.130 in Epoch 165
# Train accuracy: 0.993 in Epoch 165
# Val loss: 2.821 in Epoch 165
# Val accuracy: 0.039 in Epoch 165
# Train loss: 1.123 in Epoch 166
# Train accuracy: 0.993 in Epoch 166
# Val loss: 2.794 in Epoch 166
# Val accuracy: 0.062 in Epoch 166
# Train loss: 1.117 in Epoch 167
# Train accuracy: 0.994 in Epoch 167
# Val loss: 2.811 in Epoch 167
# Val accuracy: 0.062 in Epoch 167
# Train loss: 1.113 in Epoch 168
# Train accuracy: 0.993 in Epoch 168
# Val loss: 2.812 in Epoch 168
# Val accuracy: 0.047 in Epoch 168
# Train loss: 1.107 in Epoch 169
# Train accuracy: 0.994 in Epoch 169
# Val loss: 2.803 in Epoch 169
# Val accuracy: 0.062 in Epoch 169
# Train loss: 1.102 in Epoch 170
# Train accuracy: 0.995 in Epoch 170
# Val loss: 2.802 in Epoch 170
# Val accuracy: 0.062 in Epoch 170
# Train loss: 1.095 in Epoch 171
# Train accuracy: 0.995 in Epoch 171
# Val loss: 2.795 in Epoch 171
# Val accuracy: 0.062 in Epoch 171
# Train loss: 1.090 in Epoch 172
# Train accuracy: 0.996 in Epoch 172
# Val loss: 2.810 in Epoch 172
# Val accuracy: 0.062 in Epoch 172
# Train loss: 1.085 in Epoch 173
# Train accuracy: 0.995 in Epoch 173
# Val loss: 2.805 in Epoch 173
# Val accuracy: 0.055 in Epoch 173
# Train loss: 1.078 in Epoch 174
# Train accuracy: 0.996 in Epoch 174
# Val loss: 2.802 in Epoch 174
# Val accuracy: 0.055 in Epoch 174
# Train loss: 1.074 in Epoch 175
# Train accuracy: 0.995 in Epoch 175
# Val loss: 2.802 in Epoch 175
# Val accuracy: 0.055 in Epoch 175
# Train loss: 1.067 in Epoch 176
# Train accuracy: 0.995 in Epoch 176
# Val loss: 2.807 in Epoch 176
# Val accuracy: 0.055 in Epoch 176
# Train loss: 1.064 in Epoch 177
# Train accuracy: 0.995 in Epoch 177
# Val loss: 2.823 in Epoch 177
# Val accuracy: 0.047 in Epoch 177
# Train loss: 1.059 in Epoch 178
# Train accuracy: 0.996 in Epoch 178
# Val loss: 2.807 in Epoch 178
# Val accuracy: 0.055 in Epoch 178
# Train loss: 1.053 in Epoch 179
# Train accuracy: 0.996 in Epoch 179
# Val loss: 2.810 in Epoch 179
# Val accuracy: 0.055 in Epoch 179
# Train loss: 1.048 in Epoch 180
# Train accuracy: 0.996 in Epoch 180
# Val loss: 2.795 in Epoch 180
# Val accuracy: 0.062 in Epoch 180
# Train loss: 1.044 in Epoch 181
# Train accuracy: 0.996 in Epoch 181
# Val loss: 2.808 in Epoch 181
# Val accuracy: 0.047 in Epoch 181
# Train loss: 1.038 in Epoch 182
# Train accuracy: 0.996 in Epoch 182
# Val loss: 2.818 in Epoch 182
# Val accuracy: 0.047 in Epoch 182
# Train loss: 1.032 in Epoch 183
# Train accuracy: 0.996 in Epoch 183
# Val loss: 2.824 in Epoch 183
# Val accuracy: 0.047 in Epoch 183
# Train loss: 1.027 in Epoch 184
# Train accuracy: 0.996 in Epoch 184
# Val loss: 2.812 in Epoch 184
# Val accuracy: 0.062 in Epoch 184
# Train loss: 1.024 in Epoch 185
# Train accuracy: 0.996 in Epoch 185
# Val loss: 2.817 in Epoch 185
# Val accuracy: 0.055 in Epoch 185
# Train loss: 1.018 in Epoch 186
# Train accuracy: 0.996 in Epoch 186
# Val loss: 2.802 in Epoch 186
# Val accuracy: 0.063 in Epoch 186
# Train loss: 1.013 in Epoch 187
# Train accuracy: 0.996 in Epoch 187
# Val loss: 2.819 in Epoch 187
# Val accuracy: 0.055 in Epoch 187
# Train loss: 1.008 in Epoch 188
# Train accuracy: 0.996 in Epoch 188
# Val loss: 2.818 in Epoch 188
# Val accuracy: 0.062 in Epoch 188
# Train loss: 1.003 in Epoch 189
# Train accuracy: 0.996 in Epoch 189
# Val loss: 2.802 in Epoch 189
# Val accuracy: 0.055 in Epoch 189
# Train loss: 0.996 in Epoch 190
# Train accuracy: 0.997 in Epoch 190
# Val loss: 2.807 in Epoch 190
# Val accuracy: 0.063 in Epoch 190
# Train loss: 0.995 in Epoch 191
# Train accuracy: 0.996 in Epoch 191
# Val loss: 2.812 in Epoch 191
# Val accuracy: 0.055 in Epoch 191
# Train loss: 0.988 in Epoch 192
# Train accuracy: 0.996 in Epoch 192
# Val loss: 2.808 in Epoch 192
# Val accuracy: 0.062 in Epoch 192
# Train loss: 0.984 in Epoch 193
# Train accuracy: 0.996 in Epoch 193
# Val loss: 2.822 in Epoch 193
# Val accuracy: 0.055 in Epoch 193
# Train loss: 0.980 in Epoch 194
# Train accuracy: 0.996 in Epoch 194
# Val loss: 2.809 in Epoch 194
# Val accuracy: 0.062 in Epoch 194
# Train loss: 0.975 in Epoch 195
# Train accuracy: 0.996 in Epoch 195
# Val loss: 2.797 in Epoch 195
# Val accuracy: 0.062 in Epoch 195
# Train loss: 0.971 in Epoch 196
# Train accuracy: 0.996 in Epoch 196
# Val loss: 2.810 in Epoch 196
# Val accuracy: 0.062 in Epoch 196
# Train loss: 0.966 in Epoch 197
# Train accuracy: 0.997 in Epoch 197
# Val loss: 2.821 in Epoch 197
# Val accuracy: 0.055 in Epoch 197
# Train loss: 0.961 in Epoch 198
# Train accuracy: 0.997 in Epoch 198
# Val loss: 2.830 in Epoch 198
# Val accuracy: 0.055 in Epoch 198
# Train loss: 0.956 in Epoch 199
# Train accuracy: 0.997 in Epoch 199
# Val loss: 2.818 in Epoch 199
# Val accuracy: 0.063 in Epoch 199
# Train loss: 0.952 in Epoch 200
# Train accuracy: 0.997 in Epoch 200
# Val loss: 2.810 in Epoch 200
# Val accuracy: 0.062 in Epoch 200
# Train loss: 0.947 in Epoch 201
# Train accuracy: 0.997 in Epoch 201
# Val loss: 2.801 in Epoch 201
# Val accuracy: 0.062 in Epoch 201
# Train loss: 0.942 in Epoch 202
# Train accuracy: 0.997 in Epoch 202
# Val loss: 2.824 in Epoch 202
# Val accuracy: 0.055 in Epoch 202
# Train loss: 0.938 in Epoch 203
# Train accuracy: 0.997 in Epoch 203
# Val loss: 2.834 in Epoch 203
# Val accuracy: 0.062 in Epoch 203
# Train loss: 0.934 in Epoch 204
# Train accuracy: 0.997 in Epoch 204
# Val loss: 2.837 in Epoch 204
# Val accuracy: 0.039 in Epoch 204
# Train loss: 0.927 in Epoch 205
# Train accuracy: 0.997 in Epoch 205
# Val loss: 2.843 in Epoch 205
# Val accuracy: 0.047 in Epoch 205
# Train loss: 0.926 in Epoch 206
# Train accuracy: 0.997 in Epoch 206
# Val loss: 2.823 in Epoch 206
# Val accuracy: 0.055 in Epoch 206
# Train loss: 0.921 in Epoch 207
# Train accuracy: 0.997 in Epoch 207
# Val loss: 2.812 in Epoch 207
# Val accuracy: 0.062 in Epoch 207
# Train loss: 0.917 in Epoch 208
# Train accuracy: 0.997 in Epoch 208
# Val loss: 2.815 in Epoch 208
# Val accuracy: 0.062 in Epoch 208
# Train loss: 0.913 in Epoch 209
# Train accuracy: 0.997 in Epoch 209
# Val loss: 2.824 in Epoch 209
# Val accuracy: 0.055 in Epoch 209
# Train loss: 0.908 in Epoch 210
# Train accuracy: 0.997 in Epoch 210
# Val loss: 2.803 in Epoch 210
# Val accuracy: 0.055 in Epoch 210
# Train loss: 0.904 in Epoch 211
# Train accuracy: 0.997 in Epoch 211
# Val loss: 2.821 in Epoch 211
# Val accuracy: 0.062 in Epoch 211
# Train loss: 0.899 in Epoch 212
# Train accuracy: 0.997 in Epoch 212
# Val loss: 2.813 in Epoch 212
# Val accuracy: 0.062 in Epoch 212
# Train loss: 0.896 in Epoch 213
# Train accuracy: 0.997 in Epoch 213
# Val loss: 2.819 in Epoch 213
# Val accuracy: 0.055 in Epoch 213
# Train loss: 0.891 in Epoch 214
# Train accuracy: 0.997 in Epoch 214
# Val loss: 2.848 in Epoch 214
# Val accuracy: 0.047 in Epoch 214
# Train loss: 0.886 in Epoch 215
# Train accuracy: 0.997 in Epoch 215
# Val loss: 2.823 in Epoch 215
# Val accuracy: 0.062 in Epoch 215
# Train loss: 0.884 in Epoch 216
# Train accuracy: 0.997 in Epoch 216
# Val loss: 2.818 in Epoch 216
# Val accuracy: 0.055 in Epoch 216
# Train loss: 0.880 in Epoch 217
# Train accuracy: 0.997 in Epoch 217
# Val loss: 2.808 in Epoch 217
# Val accuracy: 0.055 in Epoch 217
# Train loss: 0.874 in Epoch 218
# Train accuracy: 0.997 in Epoch 218
# Val loss: 2.846 in Epoch 218
# Val accuracy: 0.055 in Epoch 218
# Train loss: 0.871 in Epoch 219
# Train accuracy: 0.997 in Epoch 219
# Val loss: 2.823 in Epoch 219
# Val accuracy: 0.047 in Epoch 219
# Train loss: 0.868 in Epoch 220
# Train accuracy: 0.997 in Epoch 220
# Val loss: 2.834 in Epoch 220
# Val accuracy: 0.047 in Epoch 220
# Train loss: 0.864 in Epoch 221
# Train accuracy: 0.997 in Epoch 221
# Val loss: 2.829 in Epoch 221
# Val accuracy: 0.055 in Epoch 221
# Train loss: 0.859 in Epoch 222
# Train accuracy: 0.997 in Epoch 222
# Val loss: 2.833 in Epoch 222
# Val accuracy: 0.062 in Epoch 222
# Train loss: 0.855 in Epoch 223
# Train accuracy: 0.997 in Epoch 223
# Val loss: 2.822 in Epoch 223
# Val accuracy: 0.055 in Epoch 223
# Train loss: 0.852 in Epoch 224
# Train accuracy: 0.997 in Epoch 224
# Val loss: 2.828 in Epoch 224
# Val accuracy: 0.062 in Epoch 224
# Train loss: 0.847 in Epoch 225
# Train accuracy: 0.997 in Epoch 225
# Val loss: 2.843 in Epoch 225
# Val accuracy: 0.047 in Epoch 225
# Train loss: 0.843 in Epoch 226
# Train accuracy: 0.997 in Epoch 226
# Val loss: 2.821 in Epoch 226
# Val accuracy: 0.055 in Epoch 226
# Train loss: 0.840 in Epoch 227
# Train accuracy: 0.997 in Epoch 227
# Val loss: 2.838 in Epoch 227
# Val accuracy: 0.055 in Epoch 227
# Train loss: 0.837 in Epoch 228
# Train accuracy: 0.997 in Epoch 228
# Val loss: 2.841 in Epoch 228
# Val accuracy: 0.055 in Epoch 228
# Train loss: 0.833 in Epoch 229
# Train accuracy: 0.997 in Epoch 229
# Val loss: 2.823 in Epoch 229
# Val accuracy: 0.055 in Epoch 229
# Train loss: 0.828 in Epoch 230
# Train accuracy: 0.997 in Epoch 230
# Val loss: 2.820 in Epoch 230
# Val accuracy: 0.055 in Epoch 230
# Train loss: 0.824 in Epoch 231
# Train accuracy: 0.997 in Epoch 231
# Val loss: 2.844 in Epoch 231
# Val accuracy: 0.055 in Epoch 231
# Train loss: 0.821 in Epoch 232
# Train accuracy: 0.997 in Epoch 232
# Val loss: 2.812 in Epoch 232
# Val accuracy: 0.062 in Epoch 232
# Train loss: 0.818 in Epoch 233
# Train accuracy: 0.997 in Epoch 233
# Val loss: 2.847 in Epoch 233
# Val accuracy: 0.062 in Epoch 233
# Train loss: 0.816 in Epoch 234
# Train accuracy: 0.997 in Epoch 234
# Val loss: 2.824 in Epoch 234
# Val accuracy: 0.062 in Epoch 234
# Train loss: 0.810 in Epoch 235
# Train accuracy: 0.997 in Epoch 235
# Val loss: 2.847 in Epoch 235
# Val accuracy: 0.055 in Epoch 235
# Train loss: 0.807 in Epoch 236
# Train accuracy: 0.997 in Epoch 236
# Val loss: 2.835 in Epoch 236
# Val accuracy: 0.062 in Epoch 236
# Train loss: 0.803 in Epoch 237
# Train accuracy: 0.997 in Epoch 237
# Val loss: 2.833 in Epoch 237
# Val accuracy: 0.062 in Epoch 237
# Train loss: 0.799 in Epoch 238
# Train accuracy: 0.997 in Epoch 238
# Val loss: 2.833 in Epoch 238
# Val accuracy: 0.055 in Epoch 238
# Train loss: 0.798 in Epoch 239
# Train accuracy: 0.997 in Epoch 239
# Val loss: 2.842 in Epoch 239
# Val accuracy: 0.055 in Epoch 239
# Train loss: 0.793 in Epoch 240
# Train accuracy: 0.997 in Epoch 240
# Val loss: 2.856 in Epoch 240
# Val accuracy: 0.039 in Epoch 240
# Train loss: 0.790 in Epoch 241
# Train accuracy: 0.997 in Epoch 241
# Val loss: 2.825 in Epoch 241
# Val accuracy: 0.062 in Epoch 241
# Train loss: 0.786 in Epoch 242
# Train accuracy: 0.998 in Epoch 242
# Val loss: 2.860 in Epoch 242
# Val accuracy: 0.047 in Epoch 242
# Train loss: 0.783 in Epoch 243
# Train accuracy: 0.998 in Epoch 243
# Val loss: 2.835 in Epoch 243
# Val accuracy: 0.062 in Epoch 243
# Train loss: 0.779 in Epoch 244
# Train accuracy: 0.998 in Epoch 244
# Val loss: 2.861 in Epoch 244
# Val accuracy: 0.031 in Epoch 244
# Train loss: 0.775 in Epoch 245
# Train accuracy: 0.998 in Epoch 245
# Val loss: 2.842 in Epoch 245
# Val accuracy: 0.055 in Epoch 245
# Train loss: 0.771 in Epoch 246
# Train accuracy: 0.998 in Epoch 246
# Val loss: 2.842 in Epoch 246
# Val accuracy: 0.055 in Epoch 246
# Train loss: 0.769 in Epoch 247
# Train accuracy: 0.998 in Epoch 247
# Val loss: 2.835 in Epoch 247
# Val accuracy: 0.062 in Epoch 247
# Train loss: 0.765 in Epoch 248
# Train accuracy: 0.998 in Epoch 248
# Val loss: 2.845 in Epoch 248
# Val accuracy: 0.062 in Epoch 248
# Train loss: 0.761 in Epoch 249
# Train accuracy: 0.998 in Epoch 249
# Val loss: 2.856 in Epoch 249
# Val accuracy: 0.047 in Epoch 249
# Test loss: 2.839
# Test accuracy: 0.049
#
# Top values for Class enfp:
# · imaginative: 0.57
# · imagination: 0.538
# · life: 0.49
# · enthusiasm: 0.488
# · focus: 0.452
# · ideas: 0.415
# · find: 0.394
# · communicators: 0.389
# · feeling: 0.376
# · gain: 0.334
#
# Top values for Class infp:
# · feel: 0.643
# · creative: 0.579
# · imaginative: 0.573
# · sensitivity: 0.451
# · truth: 0.448
# · cause: 0.445
# · authenticity: 0.434
# · dreams: 0.424
# · values: 0.391
# · give: 0.378
#
# Top values for Class enfj:
# · right: 0.486
# · making: 0.45
# · intuitive: 0.44
# · see: 0.417
# · best: 0.406
# · whats: 0.401
# · grow: 0.399
# · greater: 0.397
# · leadership: 0.393
# · even: 0.375
#
# Top values for Class esfj:
# · social: 0.878
# · strong: 0.61
# · moral: 0.562
# · behavior: 0.561
# · order: 0.529
# · need: 0.476
# · right: 0.457
# · care: 0.453
# · effort: 0.439
# · best: 0.406
#
# Top values for Class istp:
# · mechanical: 0.754
# · practical: 0.705
# · quite: 0.584
# · hands: 0.574
# · reserved: 0.564
# · insensitive: 0.543
# · space: 0.54
# · need: 0.483
# · go: 0.473
# · mechanics: 0.454
#
# Top values for Class istj:
# · work: 0.725
# · take: 0.691
# · order: 0.668
# · rules: 0.529
# · organization: 0.513
# · charge: 0.483
# · trust: 0.479
# · authority: 0.477
# · done: 0.472
# · way: 0.466
#
# Top values for Class estj:
# · established: 0.568
# · hardworking: 0.537
# · loyalty: 0.495
# · done: 0.493
# · relationships: 0.453
# · leave: 0.441
# · gifts: 0.428
# · giving: 0.425
# · nature: 0.425
# · loyal: 0.421
#
# Top values for Class isfj:
# · facts: 0.705
# · work: 0.424
# · order: 0.404
# · rules: 0.398
# · organizations: 0.393
# · speak: 0.387
# · integrity: 0.381
# · follow: 0.371
# · responsibilities: 0.358
# · make: 0.344
#
# Top values for Class esfp:
# · things: 0.622
# · love: 0.585
# · moment: 0.543
# · fun: 0.532
# · focus: 0.531
# · like: 0.492
# · attention: 0.488
# · conflict: 0.449
# · time: 0.446
# · friends: 0.417
#
# Top values for Class intj:
# · logical: 0.567
# · rational: 0.484
# · independent: 0.459
# · applying: 0.442
# · insight: 0.438
# · strategy: 0.424
# · knowledge: 0.411
# · rationality: 0.372
# · thinking: 0.369
# · looking: 0.367
#
# Top values for Class infj:
# · world: 0.829
# · better: 0.728
# · purpose: 0.716
# · values: 0.605
# · deep: 0.588
# · life: 0.515
# · care: 0.489
# · authentic: 0.479
# · mission: 0.457
# · close: 0.436
#
# Top values for Class isfp:
# · present: 0.699
# · moment: 0.65
# · beauty: 0.528
# · artistic: 0.51
# · life: 0.507
# · experiences: 0.493
# · live: 0.473
# · spontaneous: 0.453
# · know: 0.391
# · planning: 0.384
#
# Top values for Class entp:
# · idea: 0.803
# · ideas: 0.794
# · one: 0.528
# · new: 0.497
# · find: 0.471
# · success: 0.432
# · visionary: 0.431
# · mental: 0.385
# · confident: 0.371
# · clever: 0.365
#
# Top values for Class entj:
# · leaders: 0.8
# · achieve: 0.78
# · goals: 0.774
# · strategic: 0.609
# · ambitious: 0.516
# · goal: 0.468
# · thinking: 0.468
# · plans: 0.458
# · able: 0.435
# · careers: 0.422
#
# Top values for Class intp:
# · ideas: 0.695
# · thought: 0.634
# · get: 0.573
# · universe: 0.541
# · reason: 0.513
# · everything: 0.491
# · analyzing: 0.475
# · systems: 0.463
# · logic: 0.45
# · theory: 0.435
#
# Top values for Class estp:
# · use: 0.539
# · situations: 0.518
# · perceptive: 0.516
# · physical: 0.5
# · process: 0.438
# · keep: 0.43
# · energy: 0.403
# · thinking: 0.403
# · emotional: 0.383
# · respond: 0.381
# ........................................................
